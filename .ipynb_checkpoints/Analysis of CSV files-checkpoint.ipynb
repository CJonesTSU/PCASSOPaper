# %%
import sys
import os

# %%
class PDBEntry:
    def __init__(self, idx, name, chain):
        self.indexNum = idx
        self.name = name
        self.chain = chain

# %%
class single_AA:
    def __init__ (self, seqNum, chain, AA, SS_type):
        self.seqNum = seqNum
        self.chain = chain
        self.AA = AA
        self.SS_type = SS_type

# %%
class CSVAggregate:
    def __init__ (self, pdb_name, chain_id):
        self.pdb_name = pdb.name
        self.chain_id = chain_id
        self.PCASSO_AAs = []
        self.PDB_AAs = []
        
    def add_PCASSO_AA(self, seqNum, chain, AA, SS_type ):
        newAA = single_AA(seqNum, chain, AA, SS_type )
        self.PCASSO_AAs.append(newAA)
    
    def add_PDB_AA(self, seqNum, chain, AA, SS_type):
        newAA = single_AA(seqNum, chain, AA, SS_type )
        self.PDB_AAs.append(newAA)

# %%
notebook_path = os.path.abspath("Analysis of CSV files.ipynb")

PDBList = os.path.join(os.path.dirname(notebook_path), "DataSet/Test_Set_300.csv")
PDBs = []
with open(PDBList) as file:
    for item in file:
        item = item.rstrip('\n')
        tmp = item.split(',')
        obj = PDBEntry(tmp[0], tmp[1],tmp[2])
        PDBs.append(obj)
print(len(PDBs))
# Out:
# 300

# %%
CSVs = []
for pdb in PDBs:
    generic_path =  os.path.join(os.path.dirname(notebook_path),"PDBFiles",pdb.name)
    PCASSO_read_path = os.path.join(generic_path,pdb.name+'.csv')
    PDB_read_path = os.path.join(generic_path,pdb.name+'-pdb.csv')

    PCASSSO_in_file = open(PCASSO_read_path,'r')
    PDB_in_file = open(PDB_read_path,'r')
    lines = PCASSSO_in_file.readlines()
    name = lines[0]
    temp = CSVAggregate(name,pdb.chain)
    
    lines = lines[1:]
    for line in lines:
        parts = line.split(',')
        seqNum = int(parts[0])
        chain = parts[1]
        AA = parts[2]
        SS_type = parts[3][:1]
        temp.add_PCASSO_AA(seqNum, chain, AA, SS_type)
    
    PDB_lines = PDB_in_file.readlines()
    PDB_lines = PDB_lines[1:]
    for line in PDB_lines:
        parts = line.split(',')
        seqNum = int(parts[0])
        chain = parts[1]
        AA = parts[2]
        SS_type = parts[3][:1]
        temp.add_PDB_AA(seqNum, chain, AA, SS_type)    
    CSVs.append(temp)  
    temp = ''

# %%
global_true_helix = 0
global_true_sheet = 0
global_true_loop = 0
global_miss_H_as_S = 0
global_miss_H_as_L = 0
global_miss_S_as_H = 0
global_miss_S_as_L = 0
global_miss_L_as_S = 0
global_miss_L_as_H = 0
global_missing_AA = 0
global_PDB_H = 0
global_PDB_S = 0
global_PDB_L = 0
global_PCASSO_H = 0
global_PCASSO_S = 0
global_PCASSO_L = 0
weirdness = 0
for csv in CSVs:
    local_true_helix = 0
    local_true_sheet = 0
    local_true_loop = 0
    local_miss_H_as_S = 0
    local_miss_H_as_L = 0
    local_miss_S_as_H = 0
    local_miss_S_as_L = 0
    local_miss_L_as_S = 0
    local_miss_L_as_H = 0
    local_missing_AA = 0
    PDB_H = 0
    PDB_S = 0
    PDB_L = 0
    PCASSO_H = 0
    PCASSO_S = 0
    PCASSO_L = 0
    print(f'PDB {csv.pdb_name} chain {csv.chain_id}')
#     print(f'PCASSO\t\t\t\tPDB')
    for x in range(len(csv.PCASSO_AAs)):
#         print(len(csv.PCASSO_AAs))
#         print(len(csv.PDB_AAs))
        PCASSO_temp = csv.PCASSO_AAs[x]
        if x < len(csv.PDB_AAs):
            PDB_temp = csv.PDB_AAs[x]
        else:
            PDB_temp.seqNum = 'missing'
            PDB_temp.chain = ''
            PDB_temp.AA = ''
            PDB_temp.SS_type = 'missing'
            local_missing_AA += 1
        if csv.chain_id == PCASSO_temp.chain and csv.chain_id == PDB_temp.chain:
            pdb_type = PDB_temp.SS_type
            PCASSO_type = PCASSO_temp.SS_type
            if PCASSO_type == 'H':
                PCASSO_H += 1
            elif PCASSO_type == 'E':
                PCASSO_S += 1
            elif PCASSO_type == 'C':
                PCASSO_L += 1
            else:
                weirdness += 1
                
            if pdb_type == 'H':
                PDB_H += 1
                if PCASSO_type == 'H':
                    local_true_helix += 1
                elif PCASSO_type == 'E':
                    local_miss_H_as_S += 1
                elif PCASSO_type == 'C':
                    local_miss_H_as_L += 1
                else:
                    weirdness += 1
                    
            if pdb_type == 'E':
                PDB_S += 1
                if PCASSO_type == 'H':
                    local_miss_S_as_H += 1
                elif PCASSO_type == 'E':
                    local_true_sheet += 1
                elif PCASSO_type == 'C':
                    local_miss_S_as_L += 1
                else:
                    weirdness += 1
                    
            if pdb_type == 'C':
                PDB_L += 1
                if PCASSO_type == 'H':
                    local_miss_L_as_H += 1
                elif PCASSO_type == 'E':
                    local_miss_L_as_S += 1
                elif PCASSO_type == 'C':
                    local_true_loop += 1
                else:
                    weirdness += 1
                
            
    
    print(f'True helix {local_true_helix}, helix as sheet {local_miss_H_as_S}, helix as loop {local_miss_H_as_L}')
    print(f'True sheet {local_true_sheet}, sheet as helix {local_miss_S_as_H},  sheet as loop {local_miss_S_as_L}')
    print(f'True loop {local_true_loop}, loop as helix {local_miss_L_as_H}, loop as sheet {local_miss_L_as_S}\n')
    local_miss_H = local_miss_H_as_S + local_miss_H_as_L
    local_miss_S = local_miss_S_as_H + local_miss_S_as_L
    local_miss_L = local_miss_L_as_H + local_miss_L_as_S
    if local_true_helix != 0:
        accuracy_H = local_true_helix / (local_true_helix + local_miss_H)
    else:
        accuracy_H = 0
    
    if local_true_sheet != 0:
        accuracy_S = local_true_sheet / (local_true_sheet + local_miss_S)
    else: 
        accuracy_S = 0
    if local_true_loop != 0:
        accuracy_L = local_true_loop / (local_true_loop + local_miss_L)
    else: 
        accuracy_L = 0
    print(f'Helix accuracy = {(accuracy_H*100):.2f}')
    print(f'Sheet accuracy = {(accuracy_S * 100):.2f}')
    print(f'Loop accuracy = {(accuracy_L* 100):.2f}')
    print(f'PDB_H {PDB_H} PDB_S {PDB_S} PDB_L {PDB_L} TOTAL {PDB_H + PDB_S + PDB_L}')
    print(f'PCASSO_H {PCASSO_H} PCASSO_S {PCASSO_S} PCASSO_L {PCASSO_L} TOTAL {PCASSO_H + PCASSO_S + PCASSO_L}')
    print('\n\n')
    
    global_missing_AA += local_missing_AA
    global_true_helix += local_true_helix
    global_true_sheet += local_true_sheet
    global_true_loop += local_true_loop
          
    global_miss_H_as_S += local_miss_H_as_S
    global_miss_H_as_L += local_miss_H_as_L
    global_miss_S_as_H += local_miss_S_as_H
    global_miss_S_as_L += local_miss_S_as_L
    global_miss_L_as_H += local_miss_L_as_H
    global_miss_L_as_S += local_miss_L_as_S
    
    global_PDB_H += PDB_H
    global_PDB_S += PDB_H
    global_PDB_L += PDB_H
    global_PCASSO_H += PCASSO_H
    global_PCASSO_S += PCASSO_
    global_PCASSO_L += PCASSO_H
    
print('---=== GLOBAL VALUES ===---')  
print(f'global missing AAs {global_missing_AA}')
global_miss_H = global_miss_H_as_S + global_miss_H_as_L
global_miss_S = global_miss_S_as_H + global_miss_S_as_L
global_miss_L = global_miss_L_as_H + global_miss_L_as_S
if global_true_helix != 0:
    global_accuracy_H = global_true_helix / (global_true_helix + global_miss_H)
else:
    global_accuracy_H = 0

if global_true_sheet != 0:
    global_accuracy_S = global_true_sheet / (global_true_sheet + global_miss_S)
else: 
   global_accuracy_S = 0
if global_true_loop != 0:
    global_accuracy_L = global_miss_L / global_true_loop# / (global_true_loop + global_miss_L)
else: 
    global_accuracy_L = 0

print(f'True helix {global_true_helix}, helix as sheet {global_miss_H_as_S}, helix as loop {global_miss_H_as_L}')
print(f'Global Helix accuracy {(global_accuracy_H * 100):.2f}')
print(f'True sheet {global_true_sheet}, sheet as helix {global_miss_S_as_H},  sheet as loop {global_miss_S_as_L}')
print(f'Global Sheet accuracy {(global_accuracy_S * 100):.2f}')
print(f'True loop {global_true_loop}, loop as helix {global_miss_L_as_H}, loop as sheet {global_miss_L_as_S}')
print(f'Global Loop accuracy {(global_accuracy_L * 100):.2f}')
print(f'Weirdness {weirdness}')

print(f'GLOBAL PDB_H {global_PDB_H} PDB_S {global_PDB_S} PDB_L {global_PDB_L} TOTAL {global_PDB_H + global_PDB_S + global_PDB_L}')
print(f'GLOBAL PCASSO_H {global_PCASSO_H} PCASSO_S {global_PCASSO_S} PCASSO_L {global_PCASSO_L} TOTAL {global_PCASSO_H + global_PCASSO_S + global_PCASSO_L}')
# Out:
# PDB 1C0P chain A
# True helix 99, helix as sheet 0, helix as loop 33
# True sheet 94, sheet as helix 0,  sheet as loop 5
# True loop 119, loop as helix 5, loop as sheet 7
#
# Helix accuracy = 75.00
# Sheet accuracy = 94.95
# Loop accuracy = 90.84
# PDB_H 132 PDB_S 99 PDB_L 131 TOTAL 362
# PCASSO_H 104 PCASSO_S 101 PCASSO_L 157 TOTAL 362
#
#
#
# PDB 1DG6 chain A
# True helix 2, helix as sheet 0, helix as loop 1
# True sheet 75, sheet as helix 0,  sheet as loop 3
# True loop 65, loop as helix 1, loop as sheet 2
#
# Helix accuracy = 66.67
# Sheet accuracy = 96.15
# Loop accuracy = 95.59
# PDB_H 3 PDB_S 78 PDB_L 68 TOTAL 149
# PCASSO_H 3 PCASSO_S 77 PCASSO_L 69 TOTAL 149
#
#
#
# PDB 1GCI chain A
# True helix 50, helix as sheet 9, helix as loop 23
# True sheet 21, sheet as helix 5,  sheet as loop 26
# True loop 91, loop as helix 26, loop as sheet 18
#
# Helix accuracy = 60.98
# Sheet accuracy = 40.38
# Loop accuracy = 67.41
# PDB_H 82 PDB_S 52 PDB_L 135 TOTAL 269
# PCASSO_H 81 PCASSO_S 48 PCASSO_L 140 TOTAL 269
#
#
#
# PDB 1GS9 chain A
# True helix 118, helix as sheet 0, helix as loop 9
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 16, loop as helix 1, loop as sheet 0
#
# Helix accuracy = 92.91
# Sheet accuracy = 0.00
# Loop accuracy = 94.12
# PDB_H 127 PDB_S 0 PDB_L 17 TOTAL 144
# PCASSO_H 119 PCASSO_S 0 PCASSO_L 25 TOTAL 144
#
#
#
# PDB 1HZT chain A
# True helix 42, helix as sheet 0, helix as loop 8
# True sheet 44, sheet as helix 0,  sheet as loop 2
# True loop 49, loop as helix 0, loop as sheet 8
#
# Helix accuracy = 84.00
# Sheet accuracy = 95.65
# Loop accuracy = 85.96
# PDB_H 50 PDB_S 46 PDB_L 57 TOTAL 153
# PCASSO_H 42 PCASSO_S 52 PCASSO_L 59 TOTAL 153
#
#
#
# PDB 1I4J chain A
# True helix 40, helix as sheet 1, helix as loop 7
# True sheet 28, sheet as helix 0,  sheet as loop 6
# True loop 27, loop as helix 1, loop as sheet 0
#
# Helix accuracy = 83.33
# Sheet accuracy = 82.35
# Loop accuracy = 96.43
# PDB_H 48 PDB_S 34 PDB_L 28 TOTAL 110
# PCASSO_H 41 PCASSO_S 29 PCASSO_L 40 TOTAL 110
#
#
#
# PDB 1INL chain A
# True helix 88, helix as sheet 0, helix as loop 26
# True sheet 78, sheet as helix 0,  sheet as loop 11
# True loop 80, loop as helix 1, loop as sheet 1
#
# Helix accuracy = 77.19
# Sheet accuracy = 87.64
# Loop accuracy = 97.56
# PDB_H 114 PDB_S 89 PDB_L 82 TOTAL 285
# PCASSO_H 89 PCASSO_S 79 PCASSO_L 117 TOTAL 285
#
#
#
# PDB 1KVE chain A
# True helix 22, helix as sheet 0, helix as loop 4
# True sheet 15, sheet as helix 0,  sheet as loop 0
# True loop 20, loop as helix 0, loop as sheet 2
#
# Helix accuracy = 84.62
# Sheet accuracy = 100.00
# Loop accuracy = 90.91
# PDB_H 26 PDB_S 15 PDB_L 22 TOTAL 63
# PCASSO_H 22 PCASSO_S 17 PCASSO_L 24 TOTAL 63
#
#
#
# PDB 1LLF chain A
# True helix 187, helix as sheet 0, helix as loop 61
# True sheet 64, sheet as helix 2,  sheet as loop 9
# True loop 203, loop as helix 0, loop as sheet 8
#
# Helix accuracy = 75.40
# Sheet accuracy = 85.33
# Loop accuracy = 96.21
# PDB_H 248 PDB_S 75 PDB_L 211 TOTAL 534
# PCASSO_H 189 PCASSO_S 72 PCASSO_L 273 TOTAL 534
#
#
#
# PDB 1M22 chain A
# True helix 186, helix as sheet 0, helix as loop 45
# True sheet 64, sheet as helix 0,  sheet as loop 3
# True loop 174, loop as helix 0, loop as sheet 15
#
# Helix accuracy = 80.52
# Sheet accuracy = 95.52
# Loop accuracy = 92.06
# PDB_H 231 PDB_S 67 PDB_L 189 TOTAL 487
# PCASSO_H 186 PCASSO_S 79 PCASSO_L 222 TOTAL 487
#
#
#
# PDB 1NKD chain A
# True helix 51, helix as sheet 0, helix as loop 2
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 4, loop as helix 2, loop as sheet 0
#
# Helix accuracy = 96.23
# Sheet accuracy = 0.00
# Loop accuracy = 66.67
# PDB_H 53 PDB_S 0 PDB_L 6 TOTAL 59
# PCASSO_H 53 PCASSO_S 0 PCASSO_L 6 TOTAL 59
#
#
#
# PDB 1O06 chain A
# True helix 16, helix as sheet 0, helix as loop 2
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 2, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 88.89
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 18 PDB_S 0 PDB_L 2 TOTAL 20
# PCASSO_H 16 PCASSO_S 0 PCASSO_L 4 TOTAL 20
#
#
#
# PDB 1O98 chain A
# True helix 94, helix as sheet 51, helix as loop 90
# True sheet 9, sheet as helix 16,  sheet as loop 53
# True loop 98, loop as helix 80, loop as sheet 18
#
# Helix accuracy = 40.00
# Sheet accuracy = 11.54
# Loop accuracy = 50.00
# PDB_H 235 PDB_S 78 PDB_L 196 TOTAL 509
# PCASSO_H 190 PCASSO_S 78 PCASSO_L 241 TOTAL 509
#
#
#
# PDB 1PO5 chain A
# True helix 234, helix as sheet 2, helix as loop 41
# True sheet 31, sheet as helix 0,  sheet as loop 3
# True loop 146, loop as helix 4, loop as sheet 4
#
# Helix accuracy = 84.48
# Sheet accuracy = 91.18
# Loop accuracy = 94.81
# PDB_H 277 PDB_S 34 PDB_L 154 TOTAL 465
# PCASSO_H 238 PCASSO_S 37 PCASSO_L 190 TOTAL 465
#
#
#
# PDB 1QW9 chain A
# True helix 144, helix as sheet 0, helix as loop 29
# True sheet 110, sheet as helix 0,  sheet as loop 13
# True loop 189, loop as helix 2, loop as sheet 10
#
# Helix accuracy = 83.24
# Sheet accuracy = 89.43
# Loop accuracy = 94.03
# PDB_H 173 PDB_S 123 PDB_L 201 TOTAL 497
# PCASSO_H 146 PCASSO_S 120 PCASSO_L 231 TOTAL 497
#
#
#
# PDB 1R0U chain A
# True helix 1, helix as sheet 0, helix as loop 5
# True sheet 106, sheet as helix 0,  sheet as loop 5
# True loop 24, loop as helix 0, loop as sheet 1
#
# Helix accuracy = 16.67
# Sheet accuracy = 95.50
# Loop accuracy = 96.00
# PDB_H 6 PDB_S 111 PDB_L 25 TOTAL 142
# PCASSO_H 1 PCASSO_S 107 PCASSO_L 34 TOTAL 142
#
#
#
# PDB 1R6X chain A
# True helix 133, helix as sheet 0, helix as loop 34
# True sheet 57, sheet as helix 0,  sheet as loop 6
# True loop 132, loop as helix 5, loop as sheet 19
#
# Helix accuracy = 79.64
# Sheet accuracy = 90.48
# Loop accuracy = 84.62
# PDB_H 167 PDB_S 63 PDB_L 156 TOTAL 386
# PCASSO_H 138 PCASSO_S 76 PCASSO_L 172 TOTAL 386
#
#
#
# PDB 1R9L chain A
# True helix 135, helix as sheet 0, helix as loop 26
# True sheet 45, sheet as helix 1,  sheet as loop 9
# True loop 85, loop as helix 3, loop as sheet 4
#
# Helix accuracy = 83.85
# Sheet accuracy = 81.82
# Loop accuracy = 92.39
# PDB_H 161 PDB_S 55 PDB_L 92 TOTAL 308
# PCASSO_H 139 PCASSO_S 49 PCASSO_L 120 TOTAL 308
#
#
#
# PDB 1RFY chain A
# True helix 65, helix as sheet 0, helix as loop 7
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 17, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 90.28
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 72 PDB_S 0 PDB_L 17 TOTAL 89
# PCASSO_H 65 PCASSO_S 0 PCASSO_L 24 TOTAL 89
#
#
#
# PDB 1RH6 chain A
# True helix 15, helix as sheet 1, helix as loop 4
# True sheet 11, sheet as helix 0,  sheet as loop 3
# True loop 21, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 75.00
# Sheet accuracy = 78.57
# Loop accuracy = 100.00
# PDB_H 20 PDB_S 14 PDB_L 21 TOTAL 55
# PCASSO_H 15 PCASSO_S 12 PCASSO_L 28 TOTAL 55
#
#
#
# PDB 1T1U chain A
# True helix 263, helix as sheet 1, helix as loop 45
# True sheet 83, sheet as helix 0,  sheet as loop 3
# True loop 189, loop as helix 4, loop as sheet 9
#
# Helix accuracy = 85.11
# Sheet accuracy = 96.51
# Loop accuracy = 93.56
# PDB_H 309 PDB_S 86 PDB_L 202 TOTAL 597
# PCASSO_H 267 PCASSO_S 93 PCASSO_L 237 TOTAL 597
#
#
#
# PDB 1T7M chain B
# True helix 8, helix as sheet 0, helix as loop 2
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 2, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 80.00
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 10 PDB_S 0 PDB_L 2 TOTAL 12
# PCASSO_H 8 PCASSO_S 0 PCASSO_L 4 TOTAL 12
#
#
#
# PDB 1T9I chain A
# True helix 83, helix as sheet 0, helix as loop 11
# True sheet 30, sheet as helix 0,  sheet as loop 1
# True loop 26, loop as helix 2, loop as sheet 0
#
# Helix accuracy = 88.30
# Sheet accuracy = 96.77
# Loop accuracy = 92.86
# PDB_H 94 PDB_S 31 PDB_L 28 TOTAL 153
# PCASSO_H 85 PCASSO_S 30 PCASSO_L 38 TOTAL 153
#
#
#
# PDB 1V05 chain A
# True helix 6, helix as sheet 0, helix as loop 4
# True sheet 42, sheet as helix 0,  sheet as loop 2
# True loop 40, loop as helix 0, loop as sheet 2
#
# Helix accuracy = 60.00
# Sheet accuracy = 95.45
# Loop accuracy = 95.24
# PDB_H 10 PDB_S 44 PDB_L 42 TOTAL 96
# PCASSO_H 6 PCASSO_S 44 PCASSO_L 46 TOTAL 96
#
#
#
# PDB 1V4P chain A
# True helix 53, helix as sheet 0, helix as loop 11
# True sheet 46, sheet as helix 0,  sheet as loop 2
# True loop 36, loop as helix 0, loop as sheet 3
#
# Helix accuracy = 82.81
# Sheet accuracy = 95.83
# Loop accuracy = 92.31
# PDB_H 64 PDB_S 48 PDB_L 39 TOTAL 151
# PCASSO_H 53 PCASSO_S 49 PCASSO_L 49 TOTAL 151
#
#
#
# PDB 1V70 chain A
# True helix 3, helix as sheet 0, helix as loop 3
# True sheet 50, sheet as helix 0,  sheet as loop 5
# True loop 40, loop as helix 0, loop as sheet 4
#
# Helix accuracy = 50.00
# Sheet accuracy = 90.91
# Loop accuracy = 90.91
# PDB_H 6 PDB_S 55 PDB_L 44 TOTAL 105
# PCASSO_H 3 PCASSO_S 54 PCASSO_L 48 TOTAL 105
#
#
#
# PDB 1VKK chain A
# True helix 44, helix as sheet 0, helix as loop 13
# True sheet 36, sheet as helix 0,  sheet as loop 4
# True loop 29, loop as helix 2, loop as sheet 8
#
# Helix accuracy = 77.19
# Sheet accuracy = 90.00
# Loop accuracy = 74.36
# PDB_H 57 PDB_S 40 PDB_L 39 TOTAL 136
# PCASSO_H 46 PCASSO_S 44 PCASSO_L 46 TOTAL 136
#
#
#
# PDB 1VPT chain A
# True helix 118, helix as sheet 0, helix as loop 3
# True sheet 43, sheet as helix 0,  sheet as loop 1
# True loop 117, loop as helix 0, loop as sheet 8
#
# Helix accuracy = 97.52
# Sheet accuracy = 97.73
# Loop accuracy = 93.60
# PDB_H 121 PDB_S 44 PDB_L 125 TOTAL 290
# PCASSO_H 118 PCASSO_S 51 PCASSO_L 121 TOTAL 290
#
#
#
# PDB 1W53 chain A
# True helix 60, helix as sheet 0, helix as loop 17
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 1, loop as helix 4, loop as sheet 0
#
# Helix accuracy = 77.92
# Sheet accuracy = 0.00
# Loop accuracy = 20.00
# PDB_H 77 PDB_S 0 PDB_L 5 TOTAL 82
# PCASSO_H 64 PCASSO_S 0 PCASSO_L 18 TOTAL 82
#
#
#
# PDB 1WB4 chain A
# True helix 62, helix as sheet 4, helix as loop 43
# True sheet 31, sheet as helix 9,  sheet as loop 13
# True loop 75, loop as helix 21, loop as sheet 21
#
# Helix accuracy = 56.88
# Sheet accuracy = 58.49
# Loop accuracy = 64.10
# PDB_H 109 PDB_S 53 PDB_L 117 TOTAL 279
# PCASSO_H 92 PCASSO_S 56 PCASSO_L 131 TOTAL 279
#
#
#
# PDB 1WER chain A
# True helix 221, helix as sheet 0, helix as loop 36
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 62, loop as helix 5, loop as sheet 0
#
# Helix accuracy = 85.99
# Sheet accuracy = 0.00
# Loop accuracy = 92.54
# PDB_H 257 PDB_S 0 PDB_L 67 TOTAL 324
# PCASSO_H 226 PCASSO_S 0 PCASSO_L 98 TOTAL 324
#
#
#
# PDB 1WS8 chain A
# True helix 12, helix as sheet 0, helix as loop 9
# True sheet 31, sheet as helix 0,  sheet as loop 3
# True loop 44, loop as helix 3, loop as sheet 2
#
# Helix accuracy = 57.14
# Sheet accuracy = 91.18
# Loop accuracy = 89.80
# PDB_H 21 PDB_S 34 PDB_L 49 TOTAL 104
# PCASSO_H 15 PCASSO_S 33 PCASSO_L 56 TOTAL 104
#
#
#
# PDB 1XAK chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 37, sheet as helix 0,  sheet as loop 3
# True loop 28, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 0.00
# Sheet accuracy = 92.50
# Loop accuracy = 100.00
# PDB_H 0 PDB_S 40 PDB_L 28 TOTAL 68
# PCASSO_H 0 PCASSO_S 37 PCASSO_L 31 TOTAL 68
#
#
#
# PDB 1XBI chain A
# True helix 53, helix as sheet 0, helix as loop 11
# True sheet 16, sheet as helix 0,  sheet as loop 3
# True loop 33, loop as helix 0, loop as sheet 2
#
# Helix accuracy = 82.81
# Sheet accuracy = 84.21
# Loop accuracy = 94.29
# PDB_H 64 PDB_S 19 PDB_L 35 TOTAL 118
# PCASSO_H 53 PCASSO_S 18 PCASSO_L 47 TOTAL 118
#
#
#
# PDB 1XCR chain A
# True helix 49, helix as sheet 0, helix as loop 14
# True sheet 118, sheet as helix 0,  sheet as loop 6
# True loop 113, loop as helix 0, loop as sheet 13
#
# Helix accuracy = 77.78
# Sheet accuracy = 95.16
# Loop accuracy = 89.68
# PDB_H 63 PDB_S 124 PDB_L 126 TOTAL 313
# PCASSO_H 49 PCASSO_S 131 PCASSO_L 133 TOTAL 313
#
#
#
# PDB 1XLQ chain A
# True helix 24, helix as sheet 1, helix as loop 6
# True sheet 21, sheet as helix 0,  sheet as loop 0
# True loop 49, loop as helix 3, loop as sheet 2
#
# Helix accuracy = 77.42
# Sheet accuracy = 100.00
# Loop accuracy = 90.74
# PDB_H 31 PDB_S 21 PDB_L 54 TOTAL 106
# PCASSO_H 27 PCASSO_S 24 PCASSO_L 55 TOTAL 106
#
#
#
# PDB 1XSZ chain A
# True helix 123, helix as sheet 16, helix as loop 77
# True sheet 14, sheet as helix 12,  sheet as loop 13
# True loop 31, loop as helix 58, loop as sheet 11
#
# Helix accuracy = 56.94
# Sheet accuracy = 35.90
# Loop accuracy = 31.00
# PDB_H 216 PDB_S 39 PDB_L 100 TOTAL 355
# PCASSO_H 193 PCASSO_S 41 PCASSO_L 121 TOTAL 355
#
#
#
# PDB 1YN3 chain A
# True helix 22, helix as sheet 0, helix as loop 3
# True sheet 42, sheet as helix 0,  sheet as loop 0
# True loop 28, loop as helix 3, loop as sheet 0
#
# Helix accuracy = 88.00
# Sheet accuracy = 100.00
# Loop accuracy = 90.32
# PDB_H 25 PDB_S 42 PDB_L 31 TOTAL 98
# PCASSO_H 25 PCASSO_S 42 PCASSO_L 31 TOTAL 98
#
#
#
# PDB 1YNB chain A
# True helix 112, helix as sheet 1, helix as loop 20
# True sheet 0, sheet as helix 0,  sheet as loop 3
# True loop 29, loop as helix 1, loop as sheet 1
#
# Helix accuracy = 84.21
# Sheet accuracy = 0.00
# Loop accuracy = 93.55
# PDB_H 133 PDB_S 3 PDB_L 31 TOTAL 167
# PCASSO_H 113 PCASSO_S 2 PCASSO_L 52 TOTAL 167
#
#
#
# PDB 1ZD0 chain A
# True helix 65, helix as sheet 0, helix as loop 13
# True sheet 19, sheet as helix 0,  sheet as loop 4
# True loop 39, loop as helix 0, loop as sheet 1
#
# Helix accuracy = 83.33
# Sheet accuracy = 82.61
# Loop accuracy = 97.50
# PDB_H 78 PDB_S 23 PDB_L 40 TOTAL 141
# PCASSO_H 65 PCASSO_S 20 PCASSO_L 56 TOTAL 141
#
#
#
# PDB 1ZUU chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 8, sheet as helix 0,  sheet as loop 9
# True loop 15, loop as helix 3, loop as sheet 21
#
# Helix accuracy = 0.00
# Sheet accuracy = 47.06
# Loop accuracy = 38.46
# PDB_H 0 PDB_S 17 PDB_L 39 TOTAL 56
# PCASSO_H 3 PCASSO_S 29 PCASSO_L 24 TOTAL 56
#
#
#
# PDB 1ZY7 chain A
# True helix 128, helix as sheet 0, helix as loop 39
# True sheet 55, sheet as helix 0,  sheet as loop 5
# True loop 140, loop as helix 2, loop as sheet 9
#
# Helix accuracy = 76.65
# Sheet accuracy = 91.67
# Loop accuracy = 92.72
# PDB_H 167 PDB_S 60 PDB_L 151 TOTAL 378
# PCASSO_H 130 PCASSO_S 64 PCASSO_L 184 TOTAL 378
#
#
#
# PDB 2ABS chain A
# True helix 60, helix as sheet 45, helix as loop 61
# True sheet 15, sheet as helix 41,  sheet as loop 29
# True loop 25, loop as helix 41, loop as sheet 23
#
# Helix accuracy = 36.14
# Sheet accuracy = 17.65
# Loop accuracy = 28.09
# PDB_H 166 PDB_S 85 PDB_L 89 TOTAL 340
# PCASSO_H 142 PCASSO_S 83 PCASSO_L 115 TOTAL 340
#
#
#
# PDB 2B97 chain A
# True helix 10, helix as sheet 0, helix as loop 2
# True sheet 25, sheet as helix 0,  sheet as loop 4
# True loop 29, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 83.33
# Sheet accuracy = 86.21
# Loop accuracy = 100.00
# PDB_H 12 PDB_S 29 PDB_L 29 TOTAL 70
# PCASSO_H 10 PCASSO_S 25 PCASSO_L 35 TOTAL 70
#
#
#
# PDB 2BHU chain A
# True helix 88, helix as sheet 55, helix as loop 104
# True sheet 36, sheet as helix 28,  sheet as loop 68
# True loop 116, loop as helix 58, loop as sheet 27
#
# Helix accuracy = 35.63
# Sheet accuracy = 27.27
# Loop accuracy = 57.71
# PDB_H 247 PDB_S 132 PDB_L 201 TOTAL 580
# PCASSO_H 174 PCASSO_S 118 PCASSO_L 288 TOTAL 580
#
#
#
# PDB 2BMO chain A
# True helix 75, helix as sheet 54, helix as loop 102
# True sheet 34, sheet as helix 43,  sheet as loop 46
# True loop 29, loop as helix 35, loop as sheet 19
#
# Helix accuracy = 32.47
# Sheet accuracy = 27.64
# Loop accuracy = 34.94
# PDB_H 231 PDB_S 123 PDB_L 83 TOTAL 437
# PCASSO_H 153 PCASSO_S 107 PCASSO_L 177 TOTAL 437
#
#
#
# PDB 2C31 chain A
# True helix 200, helix as sheet 15, helix as loop 87
# True sheet 43, sheet as helix 18,  sheet as loop 32
# True loop 96, loop as helix 21, loop as sheet 34
#
# Helix accuracy = 66.23
# Sheet accuracy = 46.24
# Loop accuracy = 63.58
# PDB_H 302 PDB_S 93 PDB_L 151 TOTAL 546
# PCASSO_H 239 PCASSO_S 92 PCASSO_L 215 TOTAL 546
#
#
#
# PDB 2C8S chain A
# True helix 61, helix as sheet 0, helix as loop 15
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 69, loop as helix 0, loop as sheet 3
#
# Helix accuracy = 80.26
# Sheet accuracy = 0.00
# Loop accuracy = 95.83
# PDB_H 76 PDB_S 0 PDB_L 72 TOTAL 148
# PCASSO_H 61 PCASSO_S 3 PCASSO_L 84 TOTAL 148
#
#
#
# PDB 2CJT chain A
# True helix 3, helix as sheet 0, helix as loop 4
# True sheet 40, sheet as helix 0,  sheet as loop 33
# True loop 15, loop as helix 0, loop as sheet 24
#
# Helix accuracy = 42.86
# Sheet accuracy = 54.79
# Loop accuracy = 38.46
# PDB_H 7 PDB_S 73 PDB_L 39 TOTAL 119
# PCASSO_H 3 PCASSO_S 64 PCASSO_L 52 TOTAL 119
#
#
#
# PDB 2DE3 chain A
# True helix 175, helix as sheet 1, helix as loop 46
# True sheet 50, sheet as helix 0,  sheet as loop 6
# True loop 64, loop as helix 1, loop as sheet 1
#
# Helix accuracy = 78.83
# Sheet accuracy = 89.29
# Loop accuracy = 96.97
# PDB_H 222 PDB_S 56 PDB_L 66 TOTAL 344
# PCASSO_H 176 PCASSO_S 52 PCASSO_L 116 TOTAL 344
#
#
#
# PDB 2DTJ chain A
# True helix 56, helix as sheet 0, helix as loop 8
# True sheet 55, sheet as helix 0,  sheet as loop 4
# True loop 38, loop as helix 2, loop as sheet 1
#
# Helix accuracy = 87.50
# Sheet accuracy = 93.22
# Loop accuracy = 92.68
# PDB_H 64 PDB_S 59 PDB_L 41 TOTAL 164
# PCASSO_H 58 PCASSO_S 56 PCASSO_L 50 TOTAL 164
#
#
#
# PDB 2END chain A
# True helix 55, helix as sheet 0, helix as loop 6
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 57, loop as helix 15, loop as sheet 4
#
# Helix accuracy = 90.16
# Sheet accuracy = 0.00
# Loop accuracy = 75.00
# PDB_H 61 PDB_S 0 PDB_L 76 TOTAL 137
# PCASSO_H 70 PCASSO_S 4 PCASSO_L 63 TOTAL 137
#
#
#
# PDB 2F0C chain A
# True helix 16, helix as sheet 0, helix as loop 4
# True sheet 59, sheet as helix 0,  sheet as loop 2
# True loop 47, loop as helix 0, loop as sheet 19
#
# Helix accuracy = 80.00
# Sheet accuracy = 96.72
# Loop accuracy = 71.21
# PDB_H 20 PDB_S 61 PDB_L 66 TOTAL 147
# PCASSO_H 16 PCASSO_S 78 PCASSO_L 53 TOTAL 147
#
#
#
# PDB 2F1F chain A
# True helix 46, helix as sheet 0, helix as loop 13
# True sheet 67, sheet as helix 0,  sheet as loop 2
# True loop 34, loop as helix 0, loop as sheet 1
#
# Helix accuracy = 77.97
# Sheet accuracy = 97.10
# Loop accuracy = 97.14
# PDB_H 59 PDB_S 69 PDB_L 35 TOTAL 163
# PCASSO_H 46 PCASSO_S 68 PCASSO_L 49 TOTAL 163
#
#
#
# PDB 2GRR chain B
# True helix 104, helix as sheet 0, helix as loop 16
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 37, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 86.67
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 120 PDB_S 0 PDB_L 37 TOTAL 157
# PCASSO_H 104 PCASSO_S 0 PCASSO_L 53 TOTAL 157
#
#
#
# PDB 2HFT chain A
# True helix 7, helix as sheet 2, helix as loop 10
# True sheet 58, sheet as helix 1,  sheet as loop 18
# True loop 74, loop as helix 3, loop as sheet 32
#
# Helix accuracy = 36.84
# Sheet accuracy = 75.32
# Loop accuracy = 67.89
# PDB_H 19 PDB_S 77 PDB_L 109 TOTAL 205
# PCASSO_H 11 PCASSO_S 92 PCASSO_L 102 TOTAL 205
#
#
#
# PDB 2HJE chain A
# True helix 80, helix as sheet 0, helix as loop 17
# True sheet 67, sheet as helix 0,  sheet as loop 3
# True loop 40, loop as helix 0, loop as sheet 3
#
# Helix accuracy = 82.47
# Sheet accuracy = 95.71
# Loop accuracy = 93.02
# PDB_H 97 PDB_S 70 PDB_L 43 TOTAL 210
# PCASSO_H 80 PCASSO_S 70 PCASSO_L 60 TOTAL 210
#
#
#
# PDB 2IC6 chain A
# True helix 66, helix as sheet 0, helix as loop 4
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 1, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 94.29
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 70 PDB_S 0 PDB_L 1 TOTAL 71
# PCASSO_H 66 PCASSO_S 0 PCASSO_L 5 TOTAL 71
#
#
#
# PDB 2J5Y chain A
# True helix 26, helix as sheet 0, helix as loop 15
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 8, loop as helix 6, loop as sheet 0
#
# Helix accuracy = 63.41
# Sheet accuracy = 0.00
# Loop accuracy = 57.14
# PDB_H 41 PDB_S 0 PDB_L 14 TOTAL 55
# PCASSO_H 32 PCASSO_S 0 PCASSO_L 23 TOTAL 55
#
#
#
# PDB 2JEK chain A
# True helix 87, helix as sheet 0, helix as loop 18
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 34, loop as helix 1, loop as sheet 0
#
# Helix accuracy = 82.86
# Sheet accuracy = 0.00
# Loop accuracy = 97.14
# PDB_H 105 PDB_S 0 PDB_L 35 TOTAL 140
# PCASSO_H 88 PCASSO_S 0 PCASSO_L 52 TOTAL 140
#
#
#
# PDB 2NS9 chain A
# True helix 38, helix as sheet 0, helix as loop 11
# True sheet 69, sheet as helix 1,  sheet as loop 14
# True loop 13, loop as helix 0, loop as sheet 5
#
# Helix accuracy = 77.55
# Sheet accuracy = 82.14
# Loop accuracy = 72.22
# PDB_H 49 PDB_S 84 PDB_L 18 TOTAL 151
# PCASSO_H 39 PCASSO_S 74 PCASSO_L 38 TOTAL 151
#
#
#
# PDB 2QCP chain X
# True helix 0, helix as sheet 0, helix as loop 5
# True sheet 3, sheet as helix 0,  sheet as loop 30
# True loop 23, loop as helix 0, loop as sheet 2
#
# Helix accuracy = 0.00
# Sheet accuracy = 9.09
# Loop accuracy = 92.00
# PDB_H 5 PDB_S 33 PDB_L 25 TOTAL 63
# PCASSO_H 0 PCASSO_S 5 PCASSO_L 58 TOTAL 63
#
#
#
# PDB 2QFA chain C
# True helix 17, helix as sheet 0, helix as loop 3
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 2, loop as helix 2, loop as sheet 0
#
# Helix accuracy = 85.00
# Sheet accuracy = 0.00
# Loop accuracy = 50.00
# PDB_H 20 PDB_S 0 PDB_L 4 TOTAL 24
# PCASSO_H 19 PCASSO_S 0 PCASSO_L 5 TOTAL 24
#
#
#
# PDB 2QKP chain A
# True helix 35, helix as sheet 0, helix as loop 17
# True sheet 38, sheet as helix 2,  sheet as loop 6
# True loop 32, loop as helix 0, loop as sheet 8
#
# Helix accuracy = 67.31
# Sheet accuracy = 82.61
# Loop accuracy = 80.00
# PDB_H 52 PDB_S 46 PDB_L 40 TOTAL 138
# PCASSO_H 37 PCASSO_S 46 PCASSO_L 55 TOTAL 138
#
#
#
# PDB 2R16 chain A
# True helix 0, helix as sheet 3, helix as loop 4
# True sheet 46, sheet as helix 6,  sheet as loop 41
# True loop 36, loop as helix 0, loop as sheet 39
#
# Helix accuracy = 0.00
# Sheet accuracy = 49.46
# Loop accuracy = 48.00
# PDB_H 7 PDB_S 93 PDB_L 75 TOTAL 175
# PCASSO_H 6 PCASSO_S 88 PCASSO_L 81 TOTAL 175
#
#
#
# PDB 2R60 chain A
# True helix 212, helix as sheet 0, helix as loop 48
# True sheet 61, sheet as helix 0,  sheet as loop 2
# True loop 122, loop as helix 9, loop as sheet 2
#
# Helix accuracy = 81.54
# Sheet accuracy = 96.83
# Loop accuracy = 91.73
# PDB_H 260 PDB_S 63 PDB_L 133 TOTAL 456
# PCASSO_H 221 PCASSO_S 63 PCASSO_L 172 TOTAL 456
#
#
#
# PDB 2VNG chain A
# True helix 7, helix as sheet 0, helix as loop 3
# True sheet 28, sheet as helix 3,  sheet as loop 42
# True loop 50, loop as helix 1, loop as sheet 32
#
# Helix accuracy = 70.00
# Sheet accuracy = 38.36
# Loop accuracy = 60.24
# PDB_H 10 PDB_S 73 PDB_L 83 TOTAL 166
# PCASSO_H 11 PCASSO_S 60 PCASSO_L 95 TOTAL 166
#
#
#
# PDB 2W31 chain A
# True helix 96, helix as sheet 0, helix as loop 36
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 8, loop as helix 3, loop as sheet 0
#
# Helix accuracy = 72.73
# Sheet accuracy = 0.00
# Loop accuracy = 72.73
# PDB_H 132 PDB_S 0 PDB_L 11 TOTAL 143
# PCASSO_H 99 PCASSO_S 0 PCASSO_L 44 TOTAL 143
#
#
#
# PDB 2WY4 chain A
# True helix 119, helix as sheet 0, helix as loop 15
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 5, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 88.81
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 134 PDB_S 0 PDB_L 5 TOTAL 139
# PCASSO_H 119 PCASSO_S 0 PCASSO_L 20 TOTAL 139
#
#
#
# PDB 2WZB chain A
# True helix 127, helix as sheet 8, helix as loop 66
# True sheet 32, sheet as helix 9,  sheet as loop 26
# True loop 82, loop as helix 19, loop as sheet 34
#
# Helix accuracy = 63.18
# Sheet accuracy = 47.76
# Loop accuracy = 60.74
# PDB_H 201 PDB_S 67 PDB_L 135 TOTAL 403
# PCASSO_H 155 PCASSO_S 74 PCASSO_L 174 TOTAL 403
#
#
#
# PDB 2XGR chain A
# True helix 23, helix as sheet 3, helix as loop 17
# True sheet 35, sheet as helix 0,  sheet as loop 24
# True loop 65, loop as helix 3, loop as sheet 25
#
# Helix accuracy = 53.49
# Sheet accuracy = 59.32
# Loop accuracy = 69.89
# PDB_H 43 PDB_S 59 PDB_L 93 TOTAL 195
# PCASSO_H 26 PCASSO_S 63 PCASSO_L 106 TOTAL 195
#
#
#
# PDB 2XHF chain B
# True helix 45, helix as sheet 0, helix as loop 15
# True sheet 34, sheet as helix 0,  sheet as loop 1
# True loop 54, loop as helix 0, loop as sheet 5
#
# Helix accuracy = 75.00
# Sheet accuracy = 97.14
# Loop accuracy = 91.53
# PDB_H 60 PDB_S 35 PDB_L 59 TOTAL 154
# PCASSO_H 45 PCASSO_S 39 PCASSO_L 70 TOTAL 154
#
#
#
# PDB 2XQQ chain A
# True helix 19, helix as sheet 10, helix as loop 18
# True sheet 12, sheet as helix 0,  sheet as loop 12
# True loop 4, loop as helix 1, loop as sheet 4
#
# Helix accuracy = 40.43
# Sheet accuracy = 50.00
# Loop accuracy = 44.44
# PDB_H 47 PDB_S 24 PDB_L 9 TOTAL 80
# PCASSO_H 20 PCASSO_S 26 PCASSO_L 34 TOTAL 80
#
#
#
# PDB 2XZE chain Q
# True helix 13, helix as sheet 0, helix as loop 1
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 0, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 92.86
# Sheet accuracy = 0.00
# Loop accuracy = 0.00
# PDB_H 14 PDB_S 0 PDB_L 0 TOTAL 14
# PCASSO_H 13 PCASSO_S 0 PCASSO_L 1 TOTAL 14
#
#
#
# PDB 2Y8Y chain A
# True helix 50, helix as sheet 0, helix as loop 15
# True sheet 59, sheet as helix 0,  sheet as loop 15
# True loop 48, loop as helix 0, loop as sheet 13
#
# Helix accuracy = 76.92
# Sheet accuracy = 79.73
# Loop accuracy = 78.69
# PDB_H 65 PDB_S 74 PDB_L 61 TOTAL 200
# PCASSO_H 50 PCASSO_S 72 PCASSO_L 78 TOTAL 200
#
#
#
# PDB 2YH6 chain A
# True helix 27, helix as sheet 1, helix as loop 11
# True sheet 36, sheet as helix 2,  sheet as loop 9
# True loop 16, loop as helix 1, loop as sheet 3
#
# Helix accuracy = 69.23
# Sheet accuracy = 76.60
# Loop accuracy = 80.00
# PDB_H 39 PDB_S 47 PDB_L 20 TOTAL 106
# PCASSO_H 30 PCASSO_S 40 PCASSO_L 36 TOTAL 106
#
#
#
# PDB 2YV9 chain A
# True helix 139, helix as sheet 2, helix as loop 49
# True sheet 14, sheet as helix 1,  sheet as loop 7
# True loop 49, loop as helix 17, loop as sheet 6
#
# Helix accuracy = 73.16
# Sheet accuracy = 63.64
# Loop accuracy = 68.06
# PDB_H 190 PDB_S 22 PDB_L 72 TOTAL 284
# PCASSO_H 157 PCASSO_S 22 PCASSO_L 105 TOTAL 284
#
#
#
# PDB 3A57 chain A
# True helix 0, helix as sheet 7, helix as loop 14
# True sheet 55, sheet as helix 4,  sheet as loop 31
# True loop 26, loop as helix 0, loop as sheet 11
#
# Helix accuracy = 0.00
# Sheet accuracy = 61.11
# Loop accuracy = 70.27
# PDB_H 21 PDB_S 90 PDB_L 37 TOTAL 148
# PCASSO_H 4 PCASSO_S 73 PCASSO_L 71 TOTAL 148
#
#
#
# PDB 3AA0 chain C
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 0, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 0.00
# Sheet accuracy = 0.00
# Loop accuracy = 0.00
# PDB_H 0 PDB_S 0 PDB_L 0 TOTAL 0
# PCASSO_H 0 PCASSO_S 0 PCASSO_L 0 TOTAL 0
#
#
#
# PDB 3ACX chain A
# True helix 209, helix as sheet 0, helix as loop 31
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 43, loop as helix 1, loop as sheet 0
#
# Helix accuracy = 87.08
# Sheet accuracy = 0.00
# Loop accuracy = 97.73
# PDB_H 240 PDB_S 0 PDB_L 44 TOTAL 284
# PCASSO_H 210 PCASSO_S 0 PCASSO_L 74 TOTAL 284
#
#
#
# PDB 3AEI chain A
# True helix 70, helix as sheet 0, helix as loop 5
# True sheet 4, sheet as helix 2,  sheet as loop 4
# True loop 5, loop as helix 0, loop as sheet 4
#
# Helix accuracy = 93.33
# Sheet accuracy = 40.00
# Loop accuracy = 55.56
# PDB_H 75 PDB_S 10 PDB_L 9 TOTAL 94
# PCASSO_H 72 PCASSO_S 8 PCASSO_L 14 TOTAL 94
#
#
#
# PDB 3AIA chain A
# True helix 65, helix as sheet 0, helix as loop 20
# True sheet 40, sheet as helix 0,  sheet as loop 5
# True loop 64, loop as helix 2, loop as sheet 4
#
# Helix accuracy = 76.47
# Sheet accuracy = 88.89
# Loop accuracy = 91.43
# PDB_H 85 PDB_S 45 PDB_L 70 TOTAL 200
# PCASSO_H 67 PCASSO_S 44 PCASSO_L 89 TOTAL 200
#
#
#
# PDB 3B6E chain A
# True helix 54, helix as sheet 12, helix as loop 47
# True sheet 0, sheet as helix 15,  sheet as loop 8
# True loop 21, loop as helix 11, loop as sheet 6
#
# Helix accuracy = 47.79
# Sheet accuracy = 0.00
# Loop accuracy = 55.26
# PDB_H 113 PDB_S 23 PDB_L 38 TOTAL 174
# PCASSO_H 80 PCASSO_S 18 PCASSO_L 76 TOTAL 174
#
#
#
# PDB 3BVX chain A
# True helix 106, helix as sheet 44, helix as loop 149
# True sheet 117, sheet as helix 30,  sheet as loop 141
# True loop 199, loop as helix 95, loop as sheet 133
#
# Helix accuracy = 35.45
# Sheet accuracy = 40.62
# Loop accuracy = 46.60
# PDB_H 299 PDB_S 288 PDB_L 427 TOTAL 1014
# PCASSO_H 231 PCASSO_S 294 PCASSO_L 489 TOTAL 1014
#
#
#
# PDB 3BWZ chain A
# True helix 0, helix as sheet 6, helix as loop 3
# True sheet 35, sheet as helix 6,  sheet as loop 24
# True loop 64, loop as helix 0, loop as sheet 23
#
# Helix accuracy = 0.00
# Sheet accuracy = 53.85
# Loop accuracy = 73.56
# PDB_H 9 PDB_S 65 PDB_L 87 TOTAL 161
# PCASSO_H 6 PCASSO_S 64 PCASSO_L 91 TOTAL 161
#
#
#
# PDB 3CBZ chain A
# True helix 8, helix as sheet 4, helix as loop 16
# True sheet 11, sheet as helix 2,  sheet as loop 21
# True loop 25, loop as helix 6, loop as sheet 6
#
# Helix accuracy = 28.57
# Sheet accuracy = 32.35
# Loop accuracy = 67.57
# PDB_H 28 PDB_S 34 PDB_L 37 TOTAL 99
# PCASSO_H 16 PCASSO_S 21 PCASSO_L 62 TOTAL 99
#
#
#
# PDB 3CJS chain B
# True helix 18, helix as sheet 1, helix as loop 15
# True sheet 23, sheet as helix 0,  sheet as loop 6
# True loop 9, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 52.94
# Sheet accuracy = 79.31
# Loop accuracy = 100.00
# PDB_H 34 PDB_S 29 PDB_L 9 TOTAL 72
# PCASSO_H 18 PCASSO_S 24 PCASSO_L 30 TOTAL 72
#
#
#
# PDB 3CKJ chain A
# True helix 32, helix as sheet 17, helix as loop 82
# True sheet 13, sheet as helix 15,  sheet as loop 29
# True loop 53, loop as helix 30, loop as sheet 20
#
# Helix accuracy = 24.43
# Sheet accuracy = 22.81
# Loop accuracy = 51.46
# PDB_H 131 PDB_S 57 PDB_L 103 TOTAL 291
# PCASSO_H 77 PCASSO_S 50 PCASSO_L 164 TOTAL 291
#
#
#
# PDB 3CL6 chain A
# True helix 98, helix as sheet 2, helix as loop 48
# True sheet 17, sheet as helix 4,  sheet as loop 15
# True loop 88, loop as helix 10, loop as sheet 18
#
# Helix accuracy = 66.22
# Sheet accuracy = 47.22
# Loop accuracy = 75.86
# PDB_H 148 PDB_S 36 PDB_L 116 TOTAL 300
# PCASSO_H 112 PCASSO_S 37 PCASSO_L 151 TOTAL 300
#
#
#
# PDB 3CUZ chain A
# True helix 124, helix as sheet 31, helix as loop 124
# True sheet 6, sheet as helix 24,  sheet as loop 37
# True loop 79, loop as helix 51, loop as sheet 24
#
# Helix accuracy = 44.44
# Sheet accuracy = 8.96
# Loop accuracy = 51.30
# PDB_H 279 PDB_S 67 PDB_L 154 TOTAL 500
# PCASSO_H 199 PCASSO_S 61 PCASSO_L 240 TOTAL 500
#
#
#
# PDB 3D3B chain A
# True helix 87, helix as sheet 0, helix as loop 31
# True sheet 0, sheet as helix 8,  sheet as loop 0
# True loop 5, loop as helix 8, loop as sheet 0
#
# Helix accuracy = 73.73
# Sheet accuracy = 0.00
# Loop accuracy = 38.46
# PDB_H 118 PDB_S 8 PDB_L 13 TOTAL 139
# PCASSO_H 103 PCASSO_S 0 PCASSO_L 36 TOTAL 139
#
#
#
# PDB 3D4U chain B
# True helix 23, helix as sheet 4, helix as loop 22
# True sheet 11, sheet as helix 0,  sheet as loop 6
# True loop 7, loop as helix 0, loop as sheet 1
#
# Helix accuracy = 46.94
# Sheet accuracy = 64.71
# Loop accuracy = 87.50
# PDB_H 49 PDB_S 17 PDB_L 8 TOTAL 74
# PCASSO_H 23 PCASSO_S 16 PCASSO_L 35 TOTAL 74
#
#
#
# PDB 3DXY chain A
# True helix 32, helix as sheet 17, helix as loop 43
# True sheet 6, sheet as helix 20,  sheet as loop 10
# True loop 55, loop as helix 5, loop as sheet 10
#
# Helix accuracy = 34.78
# Sheet accuracy = 16.67
# Loop accuracy = 78.57
# PDB_H 92 PDB_S 36 PDB_L 70 TOTAL 198
# PCASSO_H 57 PCASSO_S 33 PCASSO_L 108 TOTAL 198
#
#
#
# PDB 3EKI chain A
# True helix 133, helix as sheet 4, helix as loop 35
# True sheet 50, sheet as helix 1,  sheet as loop 20
# True loop 86, loop as helix 16, loop as sheet 21
#
# Helix accuracy = 77.33
# Sheet accuracy = 70.42
# Loop accuracy = 69.92
# PDB_H 172 PDB_S 71 PDB_L 123 TOTAL 366
# PCASSO_H 150 PCASSO_S 75 PCASSO_L 141 TOTAL 366
#
#
#
# PDB 3EZI chain A
# True helix 72, helix as sheet 0, helix as loop 24
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 1, loop as helix 7, loop as sheet 0
#
# Helix accuracy = 75.00
# Sheet accuracy = 0.00
# Loop accuracy = 12.50
# PDB_H 96 PDB_S 0 PDB_L 8 TOTAL 104
# PCASSO_H 79 PCASSO_S 0 PCASSO_L 25 TOTAL 104
#
#
#
# PDB 3FRQ chain A
# True helix 99, helix as sheet 0, helix as loop 55
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 8, loop as helix 17, loop as sheet 0
#
# Helix accuracy = 64.29
# Sheet accuracy = 0.00
# Loop accuracy = 32.00
# PDB_H 154 PDB_S 0 PDB_L 25 TOTAL 179
# PCASSO_H 116 PCASSO_S 0 PCASSO_L 63 TOTAL 179
#
#
#
# PDB 3FYM chain A
# True helix 37, helix as sheet 0, helix as loop 31
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 5, loop as helix 4, loop as sheet 0
#
# Helix accuracy = 54.41
# Sheet accuracy = 0.00
# Loop accuracy = 55.56
# PDB_H 68 PDB_S 0 PDB_L 9 TOTAL 77
# PCASSO_H 41 PCASSO_S 0 PCASSO_L 36 TOTAL 77
#
#
#
# PDB 3HE5 chain B
# True helix 44, helix as sheet 0, helix as loop 1
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 1, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 97.78
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 45 PDB_S 0 PDB_L 1 TOTAL 46
# PCASSO_H 44 PCASSO_S 0 PCASSO_L 2 TOTAL 46
#
#
#
# PDB 3IVV chain A
# True helix 3, helix as sheet 13, helix as loop 5
# True sheet 22, sheet as helix 2,  sheet as loop 42
# True loop 33, loop as helix 2, loop as sheet 7
#
# Helix accuracy = 14.29
# Sheet accuracy = 33.33
# Loop accuracy = 78.57
# PDB_H 21 PDB_S 66 PDB_L 42 TOTAL 129
# PCASSO_H 7 PCASSO_S 42 PCASSO_L 80 TOTAL 129
#
#
#
# PDB 3LBE chain A
# True helix 21, helix as sheet 2, helix as loop 4
# True sheet 48, sheet as helix 0,  sheet as loop 11
# True loop 28, loop as helix 0, loop as sheet 8
#
# Helix accuracy = 77.78
# Sheet accuracy = 81.36
# Loop accuracy = 77.78
# PDB_H 27 PDB_S 59 PDB_L 36 TOTAL 122
# PCASSO_H 21 PCASSO_S 58 PCASSO_L 43 TOTAL 122
#
#
#
# PDB 3LDC chain A
# True helix 63, helix as sheet 0, helix as loop 7
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 12, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 90.00
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 70 PDB_S 0 PDB_L 12 TOTAL 82
# PCASSO_H 63 PCASSO_S 0 PCASSO_L 19 TOTAL 82
#
#
#
# PDB 3M12 chain A
# True helix 97, helix as sheet 3, helix as loop 41
# True sheet 69, sheet as helix 3,  sheet as loop 47
# True loop 72, loop as helix 10, loop as sheet 37
#
# Helix accuracy = 68.79
# Sheet accuracy = 57.98
# Loop accuracy = 60.50
# PDB_H 141 PDB_S 119 PDB_L 119 TOTAL 379
# PCASSO_H 110 PCASSO_S 109 PCASSO_L 160 TOTAL 379
#
#
#
# PDB 3M6N chain A
# True helix 140, helix as sheet 0, helix as loop 24
# True sheet 40, sheet as helix 0,  sheet as loop 0
# True loop 57, loop as helix 0, loop as sheet 3
#
# Helix accuracy = 85.37
# Sheet accuracy = 100.00
# Loop accuracy = 95.00
# PDB_H 164 PDB_S 40 PDB_L 60 TOTAL 264
# PCASSO_H 140 PCASSO_S 43 PCASSO_L 81 TOTAL 264
#
#
#
# PDB 3M9Z chain A
# True helix 8, helix as sheet 3, helix as loop 22
# True sheet 13, sheet as helix 1,  sheet as loop 21
# True loop 22, loop as helix 10, loop as sheet 21
#
# Helix accuracy = 24.24
# Sheet accuracy = 37.14
# Loop accuracy = 41.51
# PDB_H 33 PDB_S 35 PDB_L 53 TOTAL 121
# PCASSO_H 19 PCASSO_S 37 PCASSO_L 65 TOTAL 121
#
#
#
# PDB 3MAO chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 15, sheet as helix 0,  sheet as loop 20
# True loop 47, loop as helix 0, loop as sheet 15
#
# Helix accuracy = 0.00
# Sheet accuracy = 42.86
# Loop accuracy = 75.81
# PDB_H 0 PDB_S 35 PDB_L 62 TOTAL 97
# PCASSO_H 0 PCASSO_S 30 PCASSO_L 67 TOTAL 97
#
#
#
# PDB 3MEA chain A
# True helix 0, helix as sheet 0, helix as loop 5
# True sheet 19, sheet as helix 3,  sheet as loop 35
# True loop 64, loop as helix 4, loop as sheet 27
#
# Helix accuracy = 0.00
# Sheet accuracy = 33.33
# Loop accuracy = 67.37
# PDB_H 5 PDB_S 57 PDB_L 95 TOTAL 157
# PCASSO_H 7 PCASSO_S 46 PCASSO_L 104 TOTAL 157
#
#
#
# PDB 3N08 chain A
# True helix 0, helix as sheet 10, helix as loop 6
# True sheet 10, sheet as helix 5,  sheet as loop 28
# True loop 50, loop as helix 8, loop as sheet 33
#
# Helix accuracy = 0.00
# Sheet accuracy = 23.26
# Loop accuracy = 54.95
# PDB_H 16 PDB_S 43 PDB_L 91 TOTAL 150
# PCASSO_H 13 PCASSO_S 53 PCASSO_L 84 TOTAL 150
#
#
#
# PDB 3N2W chain A
# True helix 56, helix as sheet 14, helix as loop 46
# True sheet 44, sheet as helix 12,  sheet as loop 40
# True loop 83, loop as helix 25, loop as sheet 37
#
# Helix accuracy = 48.28
# Sheet accuracy = 45.83
# Loop accuracy = 57.24
# PDB_H 116 PDB_S 96 PDB_L 145 TOTAL 357
# PCASSO_H 93 PCASSO_S 95 PCASSO_L 169 TOTAL 357
#
#
#
# PDB 3NGG chain A
# True helix 2, helix as sheet 0, helix as loop 3
# True sheet 4, sheet as helix 0,  sheet as loop 4
# True loop 24, loop as helix 0, loop as sheet 8
#
# Helix accuracy = 40.00
# Sheet accuracy = 50.00
# Loop accuracy = 75.00
# PDB_H 5 PDB_S 8 PDB_L 32 TOTAL 45
# PCASSO_H 2 PCASSO_S 12 PCASSO_L 31 TOTAL 45
#
#
#
# PDB 3NRS chain A
# True helix 154, helix as sheet 0, helix as loop 38
# True sheet 59, sheet as helix 0,  sheet as loop 12
# True loop 110, loop as helix 8, loop as sheet 19
#
# Helix accuracy = 80.21
# Sheet accuracy = 83.10
# Loop accuracy = 80.29
# PDB_H 192 PDB_S 71 PDB_L 137 TOTAL 400
# PCASSO_H 162 PCASSO_S 78 PCASSO_L 160 TOTAL 400
#
#
#
# PDB 3PE6 chain A
# True helix 58, helix as sheet 21, helix as loop 50
# True sheet 4, sheet as helix 4,  sheet as loop 33
# True loop 46, loop as helix 39, loop as sheet 14
#
# Helix accuracy = 44.96
# Sheet accuracy = 9.76
# Loop accuracy = 46.46
# PDB_H 129 PDB_S 41 PDB_L 99 TOTAL 269
# PCASSO_H 101 PCASSO_S 39 PCASSO_L 129 TOTAL 269
#
#
#
# PDB 3PIW chain A
# True helix 70, helix as sheet 0, helix as loop 42
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 15, loop as helix 20, loop as sheet 0
#
# Helix accuracy = 62.50
# Sheet accuracy = 0.00
# Loop accuracy = 42.86
# PDB_H 112 PDB_S 0 PDB_L 35 TOTAL 147
# PCASSO_H 90 PCASSO_S 0 PCASSO_L 57 TOTAL 147
#
#
#
# PDB 3Q1C chain A
# True helix 120, helix as sheet 0, helix as loop 28
# True sheet 79, sheet as helix 0,  sheet as loop 6
# True loop 114, loop as helix 1, loop as sheet 3
#
# Helix accuracy = 81.08
# Sheet accuracy = 92.94
# Loop accuracy = 96.61
# PDB_H 148 PDB_S 85 PDB_L 118 TOTAL 351
# PCASSO_H 121 PCASSO_S 82 PCASSO_L 148 TOTAL 351
#
#
#
# PDB 3QL9 chain A
# True helix 36, helix as sheet 0, helix as loop 8
# True sheet 9, sheet as helix 2,  sheet as loop 2
# True loop 52, loop as helix 4, loop as sheet 11
#
# Helix accuracy = 81.82
# Sheet accuracy = 69.23
# Loop accuracy = 77.61
# PDB_H 44 PDB_S 13 PDB_L 67 TOTAL 124
# PCASSO_H 42 PCASSO_S 20 PCASSO_L 62 TOTAL 124
#
#
#
# PDB 3QR7 chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 4, sheet as helix 0,  sheet as loop 10
# True loop 77, loop as helix 0, loop as sheet 13
#
# Helix accuracy = 0.00
# Sheet accuracy = 28.57
# Loop accuracy = 85.56
# PDB_H 0 PDB_S 14 PDB_L 90 TOTAL 104
# PCASSO_H 0 PCASSO_S 17 PCASSO_L 87 TOTAL 104
#
#
#
# PDB 3QY7 chain A
# True helix 102, helix as sheet 0, helix as loop 28
# True sheet 26, sheet as helix 1,  sheet as loop 6
# True loop 69, loop as helix 1, loop as sheet 14
#
# Helix accuracy = 78.46
# Sheet accuracy = 78.79
# Loop accuracy = 82.14
# PDB_H 130 PDB_S 33 PDB_L 84 TOTAL 247
# PCASSO_H 104 PCASSO_S 40 PCASSO_L 103 TOTAL 247
#
#
#
# PDB 3RET chain A
# True helix 80, helix as sheet 0, helix as loop 10
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 7, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 88.89
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 90 PDB_S 0 PDB_L 7 TOTAL 97
# PCASSO_H 80 PCASSO_S 0 PCASSO_L 17 TOTAL 97
#
#
#
# PDB 3RO3 chain A
# True helix 88, helix as sheet 0, helix as loop 51
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 3, loop as helix 2, loop as sheet 0
#
# Helix accuracy = 63.31
# Sheet accuracy = 0.00
# Loop accuracy = 60.00
# PDB_H 139 PDB_S 0 PDB_L 5 TOTAL 144
# PCASSO_H 90 PCASSO_S 0 PCASSO_L 54 TOTAL 144
#
#
#
# PDB 3S0A chain A
# True helix 43, helix as sheet 2, helix as loop 33
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 18, loop as helix 10, loop as sheet 0
#
# Helix accuracy = 55.13
# Sheet accuracy = 0.00
# Loop accuracy = 64.29
# PDB_H 78 PDB_S 0 PDB_L 28 TOTAL 106
# PCASSO_H 53 PCASSO_S 2 PCASSO_L 51 TOTAL 106
#
#
#
# PDB 3S2R chain A
# True helix 11, helix as sheet 0, helix as loop 3
# True sheet 17, sheet as helix 0,  sheet as loop 0
# True loop 31, loop as helix 1, loop as sheet 1
#
# Helix accuracy = 78.57
# Sheet accuracy = 100.00
# Loop accuracy = 93.94
# PDB_H 14 PDB_S 17 PDB_L 33 TOTAL 64
# PCASSO_H 12 PCASSO_S 18 PCASSO_L 34 TOTAL 64
#
#
#
# PDB 3S8G chain A
# True helix 411, helix as sheet 0, helix as loop 41
# True sheet 2, sheet as helix 0,  sheet as loop 9
# True loop 83, loop as helix 3, loop as sheet 5
#
# Helix accuracy = 90.93
# Sheet accuracy = 18.18
# Loop accuracy = 91.21
# PDB_H 452 PDB_S 11 PDB_L 91 TOTAL 554
# PCASSO_H 414 PCASSO_S 7 PCASSO_L 133 TOTAL 554
#
#
#
# PDB 3SK2 chain A
# True helix 2, helix as sheet 10, helix as loop 23
# True sheet 8, sheet as helix 0,  sheet as loop 17
# True loop 27, loop as helix 12, loop as sheet 15
#
# Helix accuracy = 5.71
# Sheet accuracy = 32.00
# Loop accuracy = 50.00
# PDB_H 35 PDB_S 25 PDB_L 54 TOTAL 114
# PCASSO_H 14 PCASSO_S 33 PCASSO_L 67 TOTAL 114
#
#
#
# PDB 3SSB chain I
# True helix 3, helix as sheet 8, helix as loop 12
# True sheet 4, sheet as helix 0,  sheet as loop 1
# True loop 1, loop as helix 0, loop as sheet 1
#
# Helix accuracy = 13.04
# Sheet accuracy = 80.00
# Loop accuracy = 50.00
# PDB_H 23 PDB_S 5 PDB_L 2 TOTAL 30
# PCASSO_H 3 PCASSO_S 13 PCASSO_L 14 TOTAL 30
#
#
#
# PDB 3TBD chain A
# True helix 0, helix as sheet 18, helix as loop 46
# True sheet 29, sheet as helix 8,  sheet as loop 64
# True loop 98, loop as helix 17, loop as sheet 33
#
# Helix accuracy = 0.00
# Sheet accuracy = 28.71
# Loop accuracy = 66.22
# PDB_H 64 PDB_S 101 PDB_L 148 TOTAL 313
# PCASSO_H 25 PCASSO_S 80 PCASSO_L 208 TOTAL 313
#
#
#
# PDB 3TEU chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 16, sheet as helix 0,  sheet as loop 35
# True loop 33, loop as helix 0, loop as sheet 11
#
# Helix accuracy = 0.00
# Sheet accuracy = 31.37
# Loop accuracy = 75.00
# PDB_H 0 PDB_S 51 PDB_L 44 TOTAL 95
# PCASSO_H 0 PCASSO_S 27 PCASSO_L 68 TOTAL 95
#
#
#
# PDB 3TM8 chain A
# True helix 90, helix as sheet 0, helix as loop 106
# True sheet 4, sheet as helix 1,  sheet as loop 18
# True loop 22, loop as helix 39, loop as sheet 11
#
# Helix accuracy = 45.92
# Sheet accuracy = 17.39
# Loop accuracy = 30.56
# PDB_H 196 PDB_S 23 PDB_L 72 TOTAL 291
# PCASSO_H 130 PCASSO_S 15 PCASSO_L 146 TOTAL 291
#
#
#
# PDB 3UP3 chain A
# True helix 155, helix as sheet 0, helix as loop 24
# True sheet 6, sheet as helix 0,  sheet as loop 0
# True loop 54, loop as helix 3, loop as sheet 0
#
# Helix accuracy = 86.59
# Sheet accuracy = 100.00
# Loop accuracy = 94.74
# PDB_H 179 PDB_S 6 PDB_L 57 TOTAL 242
# PCASSO_H 158 PCASSO_S 6 PCASSO_L 78 TOTAL 242
#
#
#
# PDB 3V1N chain A
# True helix 103, helix as sheet 10, helix as loop 37
# True sheet 29, sheet as helix 5,  sheet as loop 23
# True loop 40, loop as helix 21, loop as sheet 12
#
# Helix accuracy = 68.67
# Sheet accuracy = 50.88
# Loop accuracy = 54.79
# PDB_H 150 PDB_S 57 PDB_L 73 TOTAL 280
# PCASSO_H 129 PCASSO_S 51 PCASSO_L 100 TOTAL 280
#
#
#
# PDB 3V4K chain A
# True helix 42, helix as sheet 8, helix as loop 28
# True sheet 18, sheet as helix 6,  sheet as loop 17
# True loop 37, loop as helix 15, loop as sheet 10
#
# Helix accuracy = 53.85
# Sheet accuracy = 43.90
# Loop accuracy = 59.68
# PDB_H 78 PDB_S 41 PDB_L 62 TOTAL 181
# PCASSO_H 63 PCASSO_S 36 PCASSO_L 82 TOTAL 181
#
#
#
# PDB 3V7N chain A
# True helix 155, helix as sheet 16, helix as loop 82
# True sheet 28, sheet as helix 15,  sheet as loop 31
# True loop 63, loop as helix 42, loop as sheet 28
#
# Helix accuracy = 61.26
# Sheet accuracy = 37.84
# Loop accuracy = 47.37
# PDB_H 253 PDB_S 74 PDB_L 133 TOTAL 460
# PCASSO_H 212 PCASSO_S 72 PCASSO_L 176 TOTAL 460
#
#
#
# PDB 3VGL chain A
# True helix 131, helix as sheet 0, helix as loop 28
# True sheet 57, sheet as helix 0,  sheet as loop 6
# True loop 79, loop as helix 3, loop as sheet 8
#
# Helix accuracy = 82.39
# Sheet accuracy = 90.48
# Loop accuracy = 87.78
# PDB_H 159 PDB_S 63 PDB_L 90 TOTAL 312
# PCASSO_H 134 PCASSO_S 65 PCASSO_L 113 TOTAL 312
#
#
#
# PDB 3VJ9 chain A
# True helix 247, helix as sheet 0, helix as loop 30
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 54, loop as helix 2, loop as sheet 1
#
# Helix accuracy = 89.17
# Sheet accuracy = 0.00
# Loop accuracy = 94.74
# PDB_H 277 PDB_S 0 PDB_L 57 TOTAL 334
# PCASSO_H 249 PCASSO_S 1 PCASSO_L 84 TOTAL 334
#
#
#
# PDB 3VOR chain A
# True helix 6, helix as sheet 13, helix as loop 69
# True sheet 0, sheet as helix 0,  sheet as loop 25
# True loop 41, loop as helix 1, loop as sheet 9
#
# Helix accuracy = 6.82
# Sheet accuracy = 0.00
# Loop accuracy = 80.39
# PDB_H 88 PDB_S 25 PDB_L 51 TOTAL 164
# PCASSO_H 7 PCASSO_S 22 PCASSO_L 135 TOTAL 164
#
#
#
# PDB 3W0O chain A
# True helix 137, helix as sheet 0, helix as loop 22
# True sheet 53, sheet as helix 0,  sheet as loop 7
# True loop 64, loop as helix 6, loop as sheet 6
#
# Helix accuracy = 86.16
# Sheet accuracy = 88.33
# Loop accuracy = 84.21
# PDB_H 159 PDB_S 60 PDB_L 76 TOTAL 295
# PCASSO_H 143 PCASSO_S 59 PCASSO_L 93 TOTAL 295
#
#
#
# PDB 3WKG chain A
# True helix 216, helix as sheet 1, helix as loop 20
# True sheet 21, sheet as helix 0,  sheet as loop 2
# True loop 126, loop as helix 2, loop as sheet 22
#
# Helix accuracy = 91.14
# Sheet accuracy = 91.30
# Loop accuracy = 84.00
# PDB_H 237 PDB_S 23 PDB_L 150 TOTAL 410
# PCASSO_H 218 PCASSO_S 44 PCASSO_L 148 TOTAL 410
#
#
#
# PDB 3X0T chain A
# True helix 0, helix as sheet 3, helix as loop 2
# True sheet 22, sheet as helix 0,  sheet as loop 30
# True loop 24, loop as helix 0, loop as sheet 27
#
# Helix accuracy = 0.00
# Sheet accuracy = 42.31
# Loop accuracy = 47.06
# PDB_H 5 PDB_S 52 PDB_L 51 TOTAL 108
# PCASSO_H 0 PCASSO_S 52 PCASSO_L 56 TOTAL 108
#
#
#
# PDB 3X34 chain A
# True helix 7, helix as sheet 5, helix as loop 30
# True sheet 8, sheet as helix 0,  sheet as loop 8
# True loop 17, loop as helix 3, loop as sheet 3
#
# Helix accuracy = 16.67
# Sheet accuracy = 50.00
# Loop accuracy = 73.91
# PDB_H 42 PDB_S 16 PDB_L 23 TOTAL 81
# PCASSO_H 10 PCASSO_S 16 PCASSO_L 55 TOTAL 81
#
#
#
# PDB 3ZDB chain A
# True helix 107, helix as sheet 6, helix as loop 46
# True sheet 9, sheet as helix 3,  sheet as loop 18
# True loop 32, loop as helix 16, loop as sheet 7
#
# Helix accuracy = 67.30
# Sheet accuracy = 30.00
# Loop accuracy = 58.18
# PDB_H 159 PDB_S 30 PDB_L 55 TOTAL 244
# PCASSO_H 126 PCASSO_S 22 PCASSO_L 96 TOTAL 244
#
#
#
# PDB 3ZVS chain A
# True helix 33, helix as sheet 3, helix as loop 29
# True sheet 11, sheet as helix 6,  sheet as loop 14
# True loop 31, loop as helix 11, loop as sheet 17
#
# Helix accuracy = 50.77
# Sheet accuracy = 35.48
# Loop accuracy = 52.54
# PDB_H 65 PDB_S 31 PDB_L 59 TOTAL 155
# PCASSO_H 50 PCASSO_S 31 PCASSO_L 74 TOTAL 155
#
#
#
# PDB 4A4J chain A
# True helix 20, helix as sheet 0, helix as loop 6
# True sheet 14, sheet as helix 0,  sheet as loop 11
# True loop 11, loop as helix 2, loop as sheet 4
#
# Helix accuracy = 76.92
# Sheet accuracy = 56.00
# Loop accuracy = 64.71
# PDB_H 26 PDB_S 25 PDB_L 17 TOTAL 68
# PCASSO_H 22 PCASSO_S 18 PCASSO_L 28 TOTAL 68
#
#
#
# PDB 4ABM chain A
# True helix 73, helix as sheet 0, helix as loop 4
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 2, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 94.81
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 77 PDB_S 0 PDB_L 2 TOTAL 79
# PCASSO_H 73 PCASSO_S 0 PCASSO_L 6 TOTAL 79
#
#
#
# PDB 4AU1 chain A
# True helix 94, helix as sheet 0, helix as loop 31
# True sheet 14, sheet as helix 0,  sheet as loop 6
# True loop 43, loop as helix 8, loop as sheet 11
#
# Helix accuracy = 75.20
# Sheet accuracy = 70.00
# Loop accuracy = 69.35
# PDB_H 125 PDB_S 20 PDB_L 62 TOTAL 207
# PCASSO_H 102 PCASSO_S 25 PCASSO_L 80 TOTAL 207
#
#
#
# PDB 4B1M chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 59, sheet as helix 0,  sheet as loop 49
# True loop 24, loop as helix 0, loop as sheet 27
#
# Helix accuracy = 0.00
# Sheet accuracy = 54.63
# Loop accuracy = 47.06
# PDB_H 0 PDB_S 108 PDB_L 51 TOTAL 159
# PCASSO_H 0 PCASSO_S 86 PCASSO_L 73 TOTAL 159
#
#
#
# PDB 4BFC chain A
# True helix 59, helix as sheet 13, helix as loop 36
# True sheet 5, sheet as helix 12,  sheet as loop 14
# True loop 24, loop as helix 17, loop as sheet 7
#
# Helix accuracy = 54.63
# Sheet accuracy = 16.13
# Loop accuracy = 50.00
# PDB_H 108 PDB_S 31 PDB_L 48 TOTAL 187
# PCASSO_H 88 PCASSO_S 25 PCASSO_L 74 TOTAL 187
#
#
#
# PDB 4BOU chain A
# True helix 45, helix as sheet 6, helix as loop 22
# True sheet 7, sheet as helix 0,  sheet as loop 14
# True loop 28, loop as helix 5, loop as sheet 10
#
# Helix accuracy = 61.64
# Sheet accuracy = 33.33
# Loop accuracy = 65.12
# PDB_H 73 PDB_S 21 PDB_L 43 TOTAL 137
# PCASSO_H 50 PCASSO_S 23 PCASSO_L 64 TOTAL 137
#
#
#
# PDB 4CDP chain A
# True helix 55, helix as sheet 14, helix as loop 44
# True sheet 48, sheet as helix 12,  sheet as loop 46
# True loop 48, loop as helix 24, loop as sheet 33
#
# Helix accuracy = 48.67
# Sheet accuracy = 45.28
# Loop accuracy = 45.71
# PDB_H 113 PDB_S 106 PDB_L 105 TOTAL 324
# PCASSO_H 91 PCASSO_S 95 PCASSO_L 138 TOTAL 324
#
#
#
# PDB 4CZ5 chain A
# True helix 14, helix as sheet 0, helix as loop 3
# True sheet 2, sheet as helix 3,  sheet as loop 4
# True loop 1, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 82.35
# Sheet accuracy = 22.22
# Loop accuracy = 100.00
# PDB_H 17 PDB_S 9 PDB_L 1 TOTAL 27
# PCASSO_H 17 PCASSO_S 2 PCASSO_L 8 TOTAL 27
#
#
#
# PDB 4D0P chain A
# True helix 215, helix as sheet 9, helix as loop 84
# True sheet 0, sheet as helix 2,  sheet as loop 1
# True loop 28, loop as helix 24, loop as sheet 2
#
# Helix accuracy = 69.81
# Sheet accuracy = 0.00
# Loop accuracy = 51.85
# PDB_H 308 PDB_S 3 PDB_L 54 TOTAL 365
# PCASSO_H 241 PCASSO_S 11 PCASSO_L 113 TOTAL 365
#
#
#
# PDB 4DMV chain A
# True helix 272, helix as sheet 6, helix as loop 80
# True sheet 21, sheet as helix 0,  sheet as loop 15
# True loop 92, loop as helix 38, loop as sheet 11
#
# Helix accuracy = 75.98
# Sheet accuracy = 58.33
# Loop accuracy = 65.25
# PDB_H 358 PDB_S 36 PDB_L 141 TOTAL 535
# PCASSO_H 310 PCASSO_S 38 PCASSO_L 187 TOTAL 535
#
#
#
# PDB 4EMN chain A
# True helix 45, helix as sheet 0, helix as loop 13
# True sheet 1, sheet as helix 0,  sheet as loop 2
# True loop 20, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 77.59
# Sheet accuracy = 33.33
# Loop accuracy = 100.00
# PDB_H 58 PDB_S 3 PDB_L 20 TOTAL 81
# PCASSO_H 45 PCASSO_S 1 PCASSO_L 35 TOTAL 81
#
#
#
# PDB 4EO0 chain A
# True helix 19, helix as sheet 1, helix as loop 13
# ...
# Sheet accuracy = 58.33
# Loop accuracy = 48.44
# PDB_H 212 PDB_S 24 PDB_L 64 TOTAL 300
# PCASSO_H 188 PCASSO_S 24 PCASSO_L 88 TOTAL 300
#
#
#
# PDB 5X89 chain A
# True helix 102, helix as sheet 0, helix as loop 28
# True sheet 86, sheet as helix 1,  sheet as loop 24
# True loop 76, loop as helix 0, loop as sheet 20
#
# Helix accuracy = 78.46
# Sheet accuracy = 77.48
# Loop accuracy = 79.17
# PDB_H 130 PDB_S 111 PDB_L 96 TOTAL 337
# PCASSO_H 103 PCASSO_S 106 PCASSO_L 128 TOTAL 337
#
#
#
# PDB 5XAU chain B
# True helix 68, helix as sheet 0, helix as loop 2
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 0, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 97.14
# Sheet accuracy = 0.00
# Loop accuracy = 0.00
# PDB_H 70 PDB_S 0 PDB_L 0 TOTAL 70
# PCASSO_H 68 PCASSO_S 0 PCASSO_L 2 TOTAL 70
#
#
#
# PDB 5XBC chain A
# True helix 17, helix as sheet 0, helix as loop 2
# True sheet 45, sheet as helix 0,  sheet as loop 4
# True loop 45, loop as helix 2, loop as sheet 2
#
# Helix accuracy = 89.47
# Sheet accuracy = 91.84
# Loop accuracy = 91.84
# PDB_H 19 PDB_S 49 PDB_L 49 TOTAL 117
# PCASSO_H 19 PCASSO_S 47 PCASSO_L 51 TOTAL 117
#
#
#
# PDB 5XKX chain A
# True helix 89, helix as sheet 13, helix as loop 31
# True sheet 40, sheet as helix 5,  sheet as loop 45
# True loop 96, loop as helix 14, loop as sheet 46
#
# Helix accuracy = 66.92
# Sheet accuracy = 44.44
# Loop accuracy = 61.54
# PDB_H 133 PDB_S 90 PDB_L 156 TOTAL 379
# PCASSO_H 108 PCASSO_S 99 PCASSO_L 172 TOTAL 379
#
#
#
# PDB 5YFC chain A
# True helix 148, helix as sheet 46, helix as loop 183
# True sheet 17, sheet as helix 41,  sheet as loop 45
# True loop 85, loop as helix 69, loop as sheet 20
#
# Helix accuracy = 39.26
# Sheet accuracy = 16.50
# Loop accuracy = 48.85
# PDB_H 377 PDB_S 103 PDB_L 174 TOTAL 654
# PCASSO_H 258 PCASSO_S 83 PCASSO_L 313 TOTAL 654
#
#
#
# PDB 5YKZ chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 56, sheet as helix 0,  sheet as loop 5
# True loop 44, loop as helix 0, loop as sheet 7
#
# Helix accuracy = 0.00
# Sheet accuracy = 91.80
# Loop accuracy = 86.27
# PDB_H 0 PDB_S 61 PDB_L 51 TOTAL 112
# PCASSO_H 0 PCASSO_S 63 PCASSO_L 49 TOTAL 112
#
#
#
# PDB 5YO8 chain B
# True helix 211, helix as sheet 0, helix as loop 70
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 12, loop as helix 34, loop as sheet 0
#
# Helix accuracy = 75.09
# Sheet accuracy = 0.00
# Loop accuracy = 26.09
# PDB_H 281 PDB_S 0 PDB_L 46 TOTAL 327
# PCASSO_H 245 PCASSO_S 0 PCASSO_L 82 TOTAL 327
#
#
#
# PDB 5Z42 chain A
# True helix 39, helix as sheet 0, helix as loop 7
# True sheet 22, sheet as helix 0,  sheet as loop 0
# True loop 31, loop as helix 0, loop as sheet 3
#
# Helix accuracy = 84.78
# Sheet accuracy = 100.00
# Loop accuracy = 91.18
# PDB_H 46 PDB_S 22 PDB_L 34 TOTAL 102
# PCASSO_H 39 PCASSO_S 25 PCASSO_L 38 TOTAL 102
#
#
#
# PDB 5ZRY chain A
# True helix 33, helix as sheet 0, helix as loop 61
# True sheet 1, sheet as helix 2,  sheet as loop 3
# True loop 31, loop as helix 17, loop as sheet 5
#
# Helix accuracy = 35.11
# Sheet accuracy = 16.67
# Loop accuracy = 58.49
# PDB_H 94 PDB_S 6 PDB_L 53 TOTAL 153
# PCASSO_H 52 PCASSO_S 6 PCASSO_L 95 TOTAL 153
#
#
#
# PDB 6A5H chain A
# True helix 41, helix as sheet 0, helix as loop 8
# True sheet 50, sheet as helix 0,  sheet as loop 7
# True loop 43, loop as helix 0, loop as sheet 2
#
# Helix accuracy = 83.67
# Sheet accuracy = 87.72
# Loop accuracy = 95.56
# PDB_H 49 PDB_S 57 PDB_L 45 TOTAL 151
# PCASSO_H 41 PCASSO_S 52 PCASSO_L 58 TOTAL 151
#
#
#
# PDB 6B1K chain A
# True helix 29, helix as sheet 10, helix as loop 16
# True sheet 15, sheet as helix 5,  sheet as loop 14
# True loop 8, loop as helix 9, loop as sheet 8
#
# Helix accuracy = 52.73
# Sheet accuracy = 44.12
# Loop accuracy = 32.00
# PDB_H 55 PDB_S 34 PDB_L 25 TOTAL 114
# PCASSO_H 43 PCASSO_S 33 PCASSO_L 38 TOTAL 114
#
#
#
# PDB 6BA9 chain A
# True helix 104, helix as sheet 0, helix as loop 25
# True sheet 32, sheet as helix 0,  sheet as loop 7
# True loop 73, loop as helix 0, loop as sheet 7
#
# Helix accuracy = 80.62
# Sheet accuracy = 82.05
# Loop accuracy = 91.25
# PDB_H 129 PDB_S 39 PDB_L 80 TOTAL 248
# PCASSO_H 104 PCASSO_S 39 PCASSO_L 105 TOTAL 248
#
#
#
# PDB 6CGK chain A
# True helix 58, helix as sheet 3, helix as loop 46
# True sheet 5, sheet as helix 6,  sheet as loop 12
# True loop 23, loop as helix 17, loop as sheet 23
#
# Helix accuracy = 54.21
# Sheet accuracy = 21.74
# Loop accuracy = 36.51
# PDB_H 107 PDB_S 23 PDB_L 63 TOTAL 193
# PCASSO_H 81 PCASSO_S 31 PCASSO_L 81 TOTAL 193
#
#
#
# PDB 6CHX chain A
# True helix 22, helix as sheet 4, helix as loop 17
# True sheet 33, sheet as helix 1,  sheet as loop 36
# True loop 48, loop as helix 4, loop as sheet 48
#
# Helix accuracy = 51.16
# Sheet accuracy = 47.14
# Loop accuracy = 48.00
# PDB_H 43 PDB_S 70 PDB_L 100 TOTAL 213
# PCASSO_H 27 PCASSO_S 85 PCASSO_L 101 TOTAL 213
#
#
#
# PDB 6DTD chain A
# True helix 402, helix as sheet 27, helix as loop 220
# True sheet 37, sheet as helix 23,  sheet as loop 32
# True loop 156, loop as helix 123, loop as sheet 23
#
# Helix accuracy = 61.94
# Sheet accuracy = 40.22
# Loop accuracy = 51.66
# PDB_H 649 PDB_S 92 PDB_L 302 TOTAL 1043
# PCASSO_H 548 PCASSO_S 87 PCASSO_L 408 TOTAL 1043
#
#
#
# PDB 6DWD chain D
# True helix 246, helix as sheet 1, helix as loop 54
# True sheet 51, sheet as helix 0,  sheet as loop 10
# True loop 111, loop as helix 5, loop as sheet 3
#
# Helix accuracy = 81.73
# Sheet accuracy = 83.61
# Loop accuracy = 93.28
# PDB_H 301 PDB_S 61 PDB_L 119 TOTAL 481
# PCASSO_H 251 PCASSO_S 55 PCASSO_L 175 TOTAL 481
#
#
#
# PDB 6E1F chain B
# True helix 34, helix as sheet 0, helix as loop 27
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 4, loop as helix 11, loop as sheet 0
#
# Helix accuracy = 55.74
# Sheet accuracy = 0.00
# Loop accuracy = 26.67
# PDB_H 61 PDB_S 0 PDB_L 15 TOTAL 76
# PCASSO_H 45 PCASSO_S 0 PCASSO_L 31 TOTAL 76
#
#
#
# PDB 6E43 chain A
# True helix 195, helix as sheet 7, helix as loop 67
# True sheet 0, sheet as helix 1,  sheet as loop 7
# True loop 64, loop as helix 21, loop as sheet 8
#
# Helix accuracy = 72.49
# Sheet accuracy = 0.00
# Loop accuracy = 68.82
# PDB_H 269 PDB_S 8 PDB_L 93 TOTAL 370
# PCASSO_H 217 PCASSO_S 15 PCASSO_L 138 TOTAL 370
#
#
#
# PDB 6E6Q chain B
# True helix 13, helix as sheet 0, helix as loop 17
# True sheet 0, sheet as helix 2,  sheet as loop 3
# True loop 4, loop as helix 10, loop as sheet 1
#
# Helix accuracy = 43.33
# Sheet accuracy = 0.00
# Loop accuracy = 26.67
# PDB_H 30 PDB_S 5 PDB_L 15 TOTAL 50
# PCASSO_H 25 PCASSO_S 1 PCASSO_L 24 TOTAL 50
#
#
#
# PDB 6ECT chain A
# True helix 82, helix as sheet 20, helix as loop 36
# True sheet 23, sheet as helix 16,  sheet as loop 22
# True loop 56, loop as helix 19, loop as sheet 6
#
# Helix accuracy = 59.42
# Sheet accuracy = 37.70
# Loop accuracy = 69.14
# PDB_H 138 PDB_S 61 PDB_L 81 TOTAL 280
# PCASSO_H 117 PCASSO_S 49 PCASSO_L 114 TOTAL 280
#
#
#
# PDB 6ELV chain A
# True helix 3, helix as sheet 5, helix as loop 13
# True sheet 21, sheet as helix 8,  sheet as loop 30
# True loop 22, loop as helix 1, loop as sheet 27
#
# Helix accuracy = 14.29
# Sheet accuracy = 35.59
# Loop accuracy = 44.00
# PDB_H 21 PDB_S 59 PDB_L 50 TOTAL 130
# PCASSO_H 12 PCASSO_S 53 PCASSO_L 65 TOTAL 130
#
#
#
# PDB 6F5C chain A
# True helix 61, helix as sheet 0, helix as loop 23
# True sheet 7, sheet as helix 2,  sheet as loop 6
# True loop 4, loop as helix 2, loop as sheet 3
#
# Helix accuracy = 72.62
# Sheet accuracy = 46.67
# Loop accuracy = 44.44
# PDB_H 84 PDB_S 15 PDB_L 9 TOTAL 108
# PCASSO_H 65 PCASSO_S 10 PCASSO_L 33 TOTAL 108
#
#
#
# PDB 6FDG chain A
# True helix 39, helix as sheet 4, helix as loop 15
# True sheet 35, sheet as helix 0,  sheet as loop 19
# True loop 20, loop as helix 5, loop as sheet 17
#
# Helix accuracy = 67.24
# Sheet accuracy = 64.81
# Loop accuracy = 47.62
# PDB_H 58 PDB_S 54 PDB_L 42 TOTAL 154
# PCASSO_H 44 PCASSO_S 56 PCASSO_L 54 TOTAL 154
#
#
#
# PDB 6FF1 chain A
# True helix 20, helix as sheet 1, helix as loop 5
# True sheet 8, sheet as helix 0,  sheet as loop 16
# True loop 15, loop as helix 2, loop as sheet 2
#
# Helix accuracy = 76.92
# Sheet accuracy = 33.33
# Loop accuracy = 78.95
# PDB_H 26 PDB_S 24 PDB_L 19 TOTAL 69
# PCASSO_H 22 PCASSO_S 11 PCASSO_L 36 TOTAL 69
#
#
#
# PDB 6GZU chain A
# True helix 46, helix as sheet 5, helix as loop 53
# True sheet 8, sheet as helix 0,  sheet as loop 23
# True loop 45, loop as helix 38, loop as sheet 16
#
# Helix accuracy = 44.23
# Sheet accuracy = 25.81
# Loop accuracy = 45.45
# PDB_H 104 PDB_S 31 PDB_L 99 TOTAL 234
# PCASSO_H 84 PCASSO_S 29 PCASSO_L 121 TOTAL 234
#
#
#
# PDB 6H24 chain A
# True helix 54, helix as sheet 2, helix as loop 17
# True sheet 19, sheet as helix 5,  sheet as loop 10
# True loop 10, loop as helix 3, loop as sheet 9
#
# Helix accuracy = 73.97
# Sheet accuracy = 55.88
# Loop accuracy = 45.45
# PDB_H 73 PDB_S 34 PDB_L 22 TOTAL 129
# PCASSO_H 62 PCASSO_S 30 PCASSO_L 37 TOTAL 129
#
#
#
# PDB 6HQC chain A
# True helix 0, helix as sheet 0, helix as loop 0
# True sheet 30, sheet as helix 0,  sheet as loop 22
# True loop 44, loop as helix 0, loop as sheet 17
#
# Helix accuracy = 0.00
# Sheet accuracy = 57.69
# Loop accuracy = 72.13
# PDB_H 0 PDB_S 52 PDB_L 61 TOTAL 113
# PCASSO_H 0 PCASSO_S 47 PCASSO_L 66 TOTAL 113
#
#
#
# PDB 6HUR chain A
# True helix 118, helix as sheet 20, helix as loop 95
# True sheet 26, sheet as helix 21,  sheet as loop 16
# True loop 51, loop as helix 47, loop as sheet 28
#
# Helix accuracy = 50.64
# Sheet accuracy = 41.27
# Loop accuracy = 40.48
# PDB_H 233 PDB_S 63 PDB_L 126 TOTAL 422
# PCASSO_H 186 PCASSO_S 74 PCASSO_L 162 TOTAL 422
#
#
#
# PDB 6HYO chain A
# True helix 9, helix as sheet 10, helix as loop 21
# True sheet 2, sheet as helix 0,  sheet as loop 16
# True loop 37, loop as helix 14, loop as sheet 9
#
# Helix accuracy = 22.50
# Sheet accuracy = 11.11
# Loop accuracy = 61.67
# PDB_H 40 PDB_S 18 PDB_L 60 TOTAL 118
# PCASSO_H 23 PCASSO_S 21 PCASSO_L 74 TOTAL 118
#
#
#
# PDB 6IS8 chain B
# True helix 47, helix as sheet 6, helix as loop 28
# True sheet 10, sheet as helix 10,  sheet as loop 18
# True loop 5, loop as helix 14, loop as sheet 21
#
# Helix accuracy = 58.02
# Sheet accuracy = 26.32
# Loop accuracy = 12.50
# PDB_H 81 PDB_S 38 PDB_L 40 TOTAL 159
# PCASSO_H 71 PCASSO_S 37 PCASSO_L 51 TOTAL 159
#
#
#
# PDB 6IX5 chain B
# True helix 100, helix as sheet 31, helix as loop 98
# True sheet 8, sheet as helix 11,  sheet as loop 6
# True loop 40, loop as helix 27, loop as sheet 8
#
# Helix accuracy = 43.67
# Sheet accuracy = 32.00
# Loop accuracy = 53.33
# PDB_H 229 PDB_S 25 PDB_L 75 TOTAL 329
# PCASSO_H 138 PCASSO_S 47 PCASSO_L 144 TOTAL 329
#
#
#
# PDB 6J0P chain A
# True helix 171, helix as sheet 19, helix as loop 77
# True sheet 61, sheet as helix 12,  sheet as loop 49
# True loop 105, loop as helix 28, loop as sheet 35
#
# Helix accuracy = 64.04
# Sheet accuracy = 50.00
# Loop accuracy = 62.50
# PDB_H 267 PDB_S 122 PDB_L 168 TOTAL 557
# PCASSO_H 211 PCASSO_S 115 PCASSO_L 231 TOTAL 557
#
#
#
# PDB 6MJC chain B
# True helix 13, helix as sheet 0, helix as loop 2
# True sheet 2, sheet as helix 0,  sheet as loop 0
# True loop 10, loop as helix 0, loop as sheet 1
#
# Helix accuracy = 86.67
# Sheet accuracy = 100.00
# Loop accuracy = 90.91
# PDB_H 15 PDB_S 2 PDB_L 11 TOTAL 28
# PCASSO_H 13 PCASSO_S 3 PCASSO_L 12 TOTAL 28
#
#
#
# PDB 6N1L chain A
# True helix 120, helix as sheet 0, helix as loop 10
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 11, loop as helix 0, loop as sheet 0
#
# Helix accuracy = 92.31
# Sheet accuracy = 0.00
# Loop accuracy = 100.00
# PDB_H 130 PDB_S 0 PDB_L 11 TOTAL 141
# PCASSO_H 120 PCASSO_S 0 PCASSO_L 21 TOTAL 141
#
#
#
# PDB 6NFE chain A
# True helix 44, helix as sheet 22, helix as loop 51
# True sheet 27, sheet as helix 22,  sheet as loop 29
# True loop 48, loop as helix 27, loop as sheet 18
#
# Helix accuracy = 37.61
# Sheet accuracy = 34.62
# Loop accuracy = 51.61
# PDB_H 117 PDB_S 78 PDB_L 93 TOTAL 288
# PCASSO_H 93 PCASSO_S 67 PCASSO_L 128 TOTAL 288
#
#
#
# PDB 6OP8 chain B
# True helix 7, helix as sheet 0, helix as loop 6
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 0, loop as helix 8, loop as sheet 0
#
# Helix accuracy = 53.85
# Sheet accuracy = 0.00
# Loop accuracy = 0.00
# PDB_H 13 PDB_S 0 PDB_L 8 TOTAL 21
# PCASSO_H 15 PCASSO_S 0 PCASSO_L 6 TOTAL 21
#
#
#
# PDB 6OZD chain A
# True helix 32, helix as sheet 24, helix as loop 39
# True sheet 63, sheet as helix 21,  sheet as loop 91
# True loop 142, loop as helix 17, loop as sheet 79
#
# Helix accuracy = 33.68
# Sheet accuracy = 36.00
# Loop accuracy = 59.66
# PDB_H 95 PDB_S 175 PDB_L 238 TOTAL 508
# PCASSO_H 70 PCASSO_S 166 PCASSO_L 272 TOTAL 508
#
#
#
# PDB 6P5H chain B
# True helix 33, helix as sheet 0, helix as loop 6
# True sheet 17, sheet as helix 0,  sheet as loop 3
# True loop 38, loop as helix 1, loop as sheet 0
#
# Helix accuracy = 84.62
# Sheet accuracy = 85.00
# Loop accuracy = 97.44
# PDB_H 39 PDB_S 20 PDB_L 39 TOTAL 98
# PCASSO_H 34 PCASSO_S 17 PCASSO_L 47 TOTAL 98
#
#
#
# PDB 6PIR chain B
# True helix 85, helix as sheet 0, helix as loop 27
# True sheet 0, sheet as helix 0,  sheet as loop 0
# True loop 8, loop as helix 13, loop as sheet 0
#
# Helix accuracy = 75.89
# Sheet accuracy = 0.00
# Loop accuracy = 38.10
# PDB_H 112 PDB_S 0 PDB_L 21 TOTAL 133
# PCASSO_H 98 PCASSO_S 0 PCASSO_L 35 TOTAL 133
#
#
#
# PDB 6QAZ chain A
# True helix 0, helix as sheet 4, helix as loop 4
# True sheet 34, sheet as helix 3,  sheet as loop 33
# True loop 20, loop as helix 3, loop as sheet 23
#
# Helix accuracy = 0.00
# Sheet accuracy = 48.57
# Loop accuracy = 43.48
# PDB_H 8 PDB_S 70 PDB_L 46 TOTAL 124
# PCASSO_H 6 PCASSO_S 61 PCASSO_L 57 TOTAL 124
#
#
#
# PDB 6QEJ chain A
# True helix 90, helix as sheet 15, helix as loop 30
# True sheet 37, sheet as helix 1,  sheet as loop 48
# True loop 79, loop as helix 21, loop as sheet 39
#
# Helix accuracy = 66.67
# Sheet accuracy = 43.02
# Loop accuracy = 56.83
# PDB_H 135 PDB_S 86 PDB_L 139 TOTAL 360
# PCASSO_H 112 PCASSO_S 91 PCASSO_L 157 TOTAL 360
#
#
#
# PDB 6R4Z chain A
# True helix 96, helix as sheet 1, helix as loop 26
# True sheet 7, sheet as helix 0,  sheet as loop 7
# True loop 40, loop as helix 15, loop as sheet 6
#
# Helix accuracy = 78.05
# Sheet accuracy = 50.00
# Loop accuracy = 65.57
# PDB_H 123 PDB_S 14 PDB_L 61 TOTAL 198
# PCASSO_H 111 PCASSO_S 14 PCASSO_L 73 TOTAL 198
#
#
#
# PDB 6RNI chain A
# True helix 4, helix as sheet 0, helix as loop 2
# True sheet 58, sheet as helix 0,  sheet as loop 8
# True loop 44, loop as helix 0, loop as sheet 2
#
# Helix accuracy = 66.67
# Sheet accuracy = 87.88
# Loop accuracy = 95.65
# PDB_H 6 PDB_S 66 PDB_L 46 TOTAL 118
# PCASSO_H 4 PCASSO_S 60 PCASSO_L 54 TOTAL 118
#
#
#
# PDB 6SSH chain A
# True helix 11, helix as sheet 7, helix as loop 21
# True sheet 16, sheet as helix 5,  sheet as loop 32
# True loop 56, loop as helix 14, loop as sheet 18
#
# Helix accuracy = 28.21
# Sheet accuracy = 30.19
# Loop accuracy = 63.64
# PDB_H 39 PDB_S 53 PDB_L 88 TOTAL 180
# PCASSO_H 30 PCASSO_S 41 PCASSO_L 109 TOTAL 180
#
#
#
# PDB 6SYV chain A
# True helix 57, helix as sheet 23, helix as loop 89
# True sheet 12, sheet as helix 37,  sheet as loop 22
# True loop 88, loop as helix 45, loop as sheet 27
#
# Helix accuracy = 33.73
# Sheet accuracy = 16.90
# Loop accuracy = 55.00
# PDB_H 169 PDB_S 71 PDB_L 160 TOTAL 400
# PCASSO_H 139 PCASSO_S 62 PCASSO_L 199 TOTAL 400
#
#
#
# PDB 6T02 chain B
# True helix 25, helix as sheet 13, helix as loop 26
# True sheet 18, sheet as helix 7,  sheet as loop 11
# True loop 34, loop as helix 14, loop as sheet 10
#
# Helix accuracy = 39.06
# Sheet accuracy = 50.00
# Loop accuracy = 58.62
# PDB_H 64 PDB_S 36 PDB_L 58 TOTAL 158
# PCASSO_H 46 PCASSO_S 41 PCASSO_L 71 TOTAL 158
#
#
#
# PDB 6T0Y chain A
# True helix 40, helix as sheet 8, helix as loop 48
# True sheet 23, sheet as helix 16,  sheet as loop 22
# True loop 60, loop as helix 15, loop as sheet 34
#
# Helix accuracy = 41.67
# Sheet accuracy = 37.70
# Loop accuracy = 55.05
# PDB_H 96 PDB_S 61 PDB_L 109 TOTAL 266
# PCASSO_H 71 PCASSO_S 65 PCASSO_L 130 TOTAL 266
#
#
#
# PDB 6UQV chain A
# True helix 59, helix as sheet 12, helix as loop 71
# True sheet 7, sheet as helix 10,  sheet as loop 10
# True loop 66, loop as helix 34, loop as sheet 8
#
# Helix accuracy = 41.55
# Sheet accuracy = 25.93
# Loop accuracy = 61.11
# PDB_H 142 PDB_S 27 PDB_L 108 TOTAL 277
# PCASSO_H 103 PCASSO_S 27 PCASSO_L 147 TOTAL 277
#
#
#
# ---=== GLOBAL VALUES ===---
# global missing AAs 23
# True helix 20181, helix as sheet 1946, helix as loop 9526
# Global Helix accuracy 63.76
# True sheet 8028, sheet as helix 1346,  sheet as loop 4827
# Global Sheet accuracy 56.53
# True loop 14159, loop as helix 3479, loop as sheet 3705
# Global Loop accuracy 50.74
# Weirdness 0
# GLOBAL PDB_H 31653 PDB_S 31653 PDB_L 31653 TOTAL 94959
# GLOBAL PCASSO_H 25006 PCASSO_S 25006 PCASSO_L 25006 TOTAL 75018
